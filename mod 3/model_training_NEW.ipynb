# %% [markdown]
# ## Домашняя работа №3
# ### Задание - часть теоретическая.
# Опишите общий принцип работы сверточных нейронных сетей.
#
# Сверточные нейронные сети являются основным инструментом в области компьютерного зрения и анализа изображений. Они разработаны специально для обработки данных с пространственной структурой, таких как изображения. Основной принцип работы сверточных нейронных сетей состоит в применении операции свертки к входным данным с использованием специальных фильтров.
#
# Сверточная нейронная сеть состоит из нескольких слоев. Первый слой является входным, на котором происходит подача исходных данных, например, изображения. Затем следуют несколько слоев свертки, которые применяют фильтры к входным данным. Фильтры выделяют различные пространственные признаки, такие как границы, текстуры и формы. Затем следуют слои объединения (pooling), которые уменьшают размерность данных, усредняя или выбирая наиболее значимые значения. После этого могут следовать полносвязные слои (fully connected layers), которые выполняют классификацию или регрессию на основе выделенных признаков.
#
# Чем хороши сверточные нейронные сети?
#
# Сверточные нейронные сети хороши в обработке изображений и других данных с пространственной структурой по следующим причинам:
#
# Учитывают локальные зависимости: Сверточные слои применяют фильтры к локальным областям данных, учитывая локальные зависимости между пикселями или элементами данных. Это позволяет модели улавливать пространственные шаблоны и структуры.
#
# Параметры совместного использования: Фильтры в сверточных слоях используются повторно для обработки различных частей входных данных. Это сокращает общее количество параметров модели и позволяет эффективно использовать вычислительные ресурсы.
#
# Инвариантность к переводу искажений: Сверточные нейронные сети обладают инвариантностью к некоторым искажениям, таким как трансляции, повороты и масштабирование. Они способны распознавать объекты в изображениях, независимо от их положения или масштаба.
#
# Опишите общий принцип работы рекуррентных нейронных сетей.
#
# Рекуррентные нейронные сети предназначены для работы с последовательными данными, где важна последовательность и зависимости между элементами. Они обладают памятью, которая позволяет модели учитывать контекст предыдущих элементов при обработке текущего элемента в последовательности. Основной принцип работы рекуррентных нейронных сетей заключается в использовании рекуррентных связей и обратного распространения ошибки на протяжении временной оси.
#
# В рекуррентных нейронных сетях каждый элемент последовательности обрабатывается с использованием одной и той же модели (нейронной сети), и результат обработки передается следующему элементу в последовательности. Таким образом, сеть может сохранять информацию о предыдущих элементах и использовать ее для принятия решений или генерации выходных значений. Это делает рекуррентные нейронные сети особенно полезными в задачах, где важна последовательность данных или контекстная информация.
#
# Чем хороши рекуррентные нейронные сети?
#
# Обработка последовательных данных: Рекуррентные нейронные сети эффективно работают с временными рядами, естественным языком, речью и другими типами последовательных данных. Они могут улавливать зависимости и паттерны, которые присутствуют в этих данных.
#
# Генерация последовательностей: RNN могут использоваться для генерации новых последовательностей на основе обучающих данных. Например, они могут использоваться для генерации текста, музыки или изображений.
#
# Машинный перевод: Рекуррентные нейронные сети широко применяются в задачах машинного перевода, где необходимо переводить предложения или тексты с одного языка на другой.
#
# Приведите примеры задач, в которых можно было бы применить сверточные нейронные сети / рекуррентные нейронные сети
#
# Сверточные нейронные сети:
#
# Классификация изображений: Сверточные нейронные сети показывают отличные результаты в задачах классификации изображений, где необходимо определить, что изображено на фотографии или картинке.
#
# Детекция объектов: CNN часто используются для обнаружения и выделения объектов на изображении. Они могут помочь автоматически распознавать и выделять лица, автоматически распознавать и выделять лица, автомобили, дома и другие объекты.
#
# Рекуррентные нейронные сети:
#
# - Распознавание речи: RNN могут использоваться для распознавания и транскрибирования речи. Они способны улавливать зависимости между фонемами и словами в произнесенном тексте.
#
# - Анализ эмоциональной окраски текста: Рекуррентные нейронные сети могут применяться для анализа тональности и эмоциональной окраски текста. Они могут определить, является ли текст позитивным, негативным или нейтральным.

# %%
from gensim.models import Word2Vec
import joblib
import json
import nltk
from nltk.corpus import stopwords
import numpy as np
from pymorphy3 import MorphAnalyzer
import re
from sklearn import linear_model, metrics
from sklearn.model_selection import train_test_split
import sqlite3
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# Напишем функцию для токенизации и лемматизации слов, а также удаления стопслов из документа (поста, описания группы и любого другого текстового параметра). Функция токенизирует документ, если в нем содержалось более 2 значащих слов.

# %%
patterns = "[«»!#$%&'()*+,./:;<=>?@[\]^_`{|}~—\"\-]+"
stopwords_ru_en = stopwords.words("russian") + stopwords.words("english") + stopwords.words("german") 
morph = MorphAnalyzer()

def lemmatize(doc):
    doc = doc.lower()
    doc = re.sub(patterns, ' ', doc)
    tokens = []
    for token in doc.split():
        token = token.strip()
        if token and token not in stopwords_ru_en:
            token = morph.normal_forms(token)[0]
            tokens.append(token)
    if len(tokens) > 2:
        return tokens
    return None

stopwords_ru_en
# Out:
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между',
#  'i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'aber',
#  'alle',
#  'allem',
#  'allen',
#  'aller',
#  'alles',
#  'als',
#  'also',
#  'am',
#  'an',
#  'ander',
#  'andere',
#  'anderem',
#  'anderen',
#  'anderer',
#  'anderes',
#  'anderm',
#  'andern',
#  'anderr',
#  'anders',
#  'auch',
#  'auf',
#  'aus',
#  'bei',
#  'bin',
#  'bis',
#  'bist',
#  'da',
#  'damit',
#  'dann',
#  'der',
#  'den',
#  'des',
#  'dem',
#  'die',
#  'das',
#  'dass',
#  'daß',
#  'derselbe',
#  'derselben',
#  'denselben',
#  'desselben',
#  'demselben',
#  'dieselbe',
#  'dieselben',
#  'dasselbe',
#  'dazu',
#  'dein',
#  'deine',
#  'deinem',
#  'deinen',
#  'deiner',
#  'deines',
#  'denn',
#  'derer',
#  'dessen',
#  'dich',
#  'dir',
#  'du',
#  'dies',
#  'diese',
#  'diesem',
#  'diesen',
#  'dieser',
#  'dieses',
#  'doch',
#  'dort',
#  'durch',
#  'ein',
#  'eine',
#  'einem',
#  'einen',
#  'einer',
#  'eines',
#  'einig',
#  'einige',
#  'einigem',
#  'einigen',
#  'einiger',
#  'einiges',
#  'einmal',
#  'er',
#  'ihn',
#  'ihm',
#  'es',
#  'etwas',
#  'euer',
#  'eure',
#  'eurem',
#  'euren',
#  'eurer',
#  'eures',
#  'für',
#  'gegen',
#  'gewesen',
#  'hab',
#  'habe',
#  'haben',
#  'hat',
#  'hatte',
#  'hatten',
#  'hier',
#  'hin',
#  'hinter',
#  'ich',
#  'mich',
#  'mir',
#  'ihr',
#  'ihre',
#  'ihrem',
#  'ihren',
#  'ihrer',
#  'ihres',
#  'euch',
#  'im',
#  'in',
#  'indem',
#  'ins',
#  'ist',
#  'jede',
#  'jedem',
#  'jeden',
#  'jeder',
#  'jedes',
#  'jene',
#  'jenem',
#  'jenen',
#  'jener',
#  'jenes',
#  'jetzt',
#  'kann',
#  'kein',
#  'keine',
#  'keinem',
#  'keinen',
#  'keiner',
#  'keines',
#  'können',
#  'könnte',
#  'machen',
#  'man',
#  'manche',
#  'manchem',
#  'manchen',
#  'mancher',
#  'manches',
#  'mein',
#  'meine',
#  'meinem',
#  'meinen',
#  'meiner',
#  'meines',
#  'mit',
#  'muss',
#  'musste',
#  'nach',
#  'nicht',
#  'nichts',
#  'noch',
#  'nun',
#  'nur',
#  'ob',
#  'oder',
#  'ohne',
#  'sehr',
#  'sein',
#  'seine',
#  'seinem',
#  'seinen',
#  'seiner',
#  'seines',
#  'selbst',
#  'sich',
#  'sie',
#  'ihnen',
#  'sind',
#  'so',
#  'solche',
#  'solchem',
#  'solchen',
#  'solcher',
#  'solches',
#  'soll',
#  'sollte',
#  'sondern',
#  'sonst',
#  'über',
#  'um',
#  'und',
#  'uns',
#  'unsere',
#  'unserem',
#  'unseren',
#  'unser',
#  'unseres',
#  'unter',
#  'viel',
#  'vom',
#  'von',
#  'vor',
#  'während',
#  'war',
#  'waren',
#  'warst',
#  'was',
#  'weg',
#  'weil',
#  'weiter',
#  'welche',
#  'welchem',
#  'welchen',
#  'welcher',
#  'welches',
#  'wenn',
#  'werde',
#  'werden',
#  'wie',
#  'wieder',
#  'will',
#  'wir',
#  'wird',
#  'wirst',
#  'wo',
#  'wollen',
#  'wollte',
#  'würde',
#  'würden',
#  'zu',
#  'zum',
#  'zur',
#  'zwar',
#  'zwischen']

# %% [markdown]
# Извлечем тексты всех постов из датасета, описания групп, их названия и статусы для обучения модели word2vec, разделим данные на обучающий и тестовый датасеты.

# %%
db = sqlite3.connect('database.db')  
cursor_obj = db.cursor()
cursor_obj.execute("select * from groups")
rows = cursor_obj.fetchall()
db.close()

train_data, test_data = train_test_split(rows, test_size=0.25)

# %% [markdown]
# Соберем все тексты, которые содержатся в нашем датасете, в единый список документов

# %%
all_texts = []
for group in rows:
    name = lemmatize(group[1])
    if name is not None:
        all_texts.append(name)
    status = lemmatize(group[2])
    if status is not None:
        all_texts.append(status)
    description = lemmatize(group[3])
    if description is not None:
        all_texts.append(description)
    posts = json.loads(group[12])
    for post in posts:
        prep_post = lemmatize(post['text'])
        if prep_post is not None:
            all_texts.append(prep_post)
            
all_texts
# Out:
# [['микрокинотеатр', 'санкт', 'петербург'],
#  ['авторский',
#   'классика',
#   'новинка',
#   'фестивальный',
#   'кино',
#   'большой',
#   'экран',
#   'камерный',
#   'зал',
#   'ежедневный',
#   'показ',
#   'язык',
#   'оригинал',
#   'русский',
#   'субтитр',
#   'найти',
#   'vk',
#   'cc',
#   '8prnty'],
#  ['афиша',
#   'cinema',
#   '26',
#   'июнь',
#   '2',
#   'июль',
#   'премьерный',
#   'показ',
#   'лента',
#   'лариса',
#   'шепитько',
#   'крыло',
#   'дэн',
#   'гилрой',
#   'стрингер',
#   'михаил',
#   'калатозов',
#   'красный',
#   'палатка',
#   'авторский',
#   'код',
#   'эмир',
#   'кустурица',
#   'чёрный',
#   'кошка',
#   'белый',
#   'кот',
#   'мартин',
#   'сковбьерг',
#   'копенгаген',
#   'существовать',
#   'жак',
#   'одиар',
#   'париж',
#   '13',
#   'й',
#   'округ',
#   'франсуа',
#   'трюффо',
#   'жюля',
#   'джим',
#   'зак',
#   'брафф',
#   'хотеть',
#   'погружаться',
#   'изощрённый',
#   'визуал',
#   'увидеть',
#   'работать',
#   'фильм',
#   'ларс',
#   'фон',
#   'триер',
#   'догвилль',
#   'андрей',
#   'тарковский',
#   'ностальгия',
#   'жан',
#   'кокто',
#   'р',
#   'клеман',
#   'красавица',
#   'чудовище',
#   'ретроспектива',
#   'работа',
#   'джим',
#   'джармуш',
#   'таинственный',
#   'поезд',
#   'мертвец',
#   'кофе',
#   'сигарета',
#   'азиатский',
#   'кинематограф',
#   'возвращение',
#   'сеул',
#   'дэви',
#   'шу',
#   'украсить',
#   'прощальный',
#   'утро',
#   'цвета',
#   'обещание',
#   'марь',
#   'окады',
#   'форма',
#   'голос',
#   'наоко',
#   'ямады',
#   'дерсу',
#   'узал',
#   'акир',
#   'куросава',
#   'классический',
#   'репертуар',
#   'гражданин',
#   'кейн',
#   'орсон',
#   'уэллс',
#   'дневник',
#   'сельский',
#   'священник',
#   'робер',
#   'брессон',
#   'шанхайский',
#   'экспресс',
#   'джозеф',
#   'фон',
#   'штернберг',
#   'ретроспектива',
#   'работа',
#   'альфред',
#   'хичкок',
#   '39',
#   'ступень',
#   'незнакомец',
#   'поезд',
#   'страх',
#   'сцена',
#   'специальный',
#   'показ',
#   'лента',
#   'жак',
#   'турнера',
#   'человек',
#   'кошка',
#   'лекция',
#   'пригласить',
#   'спикер',
#   'билет',
#   'купить',
#   'онлайн',
#   'билет',
#   'расписание',
#   'outcinema',
#   'ru',
#   'найти',
#   'vk',
#   'cc',
#   '8prntyый'],
#  ['четверг',
#   '29',
#   'июнь',
#   'географический',
#   'калейдоскоп',
#   'жанровый',
#   'карусель',
#   'стилистический',
#   'коктейль',
#   '14',
#   '00',
#   'незнакомец',
#   'поезд',
#   'режиссёр',
#   'альфред',
#   'хичкок',
#   'сша',
#   '1951',
#   'билет',
#   'outcinema',
#   'ru',
#   'strangers',
#   'train',
#   '16',
#   '00',
#   'гражданин',
#   'кейн',
#   'режиссёр',
#   'орсон',
#   'уэллс',
#   'сша',
#   '1941',
#   'билет',
#   'outcinema',
#   'ru',
#   'citizen',
#   'kane',
#   '18',
#   '20',
#   'таинственный',
#   'поезд',
#   'режиссёр',
#   'джим',
#   'джармуш',
#   'сша',
#   'япония',
#   '1989',
#   'билет',
#   'outcinema',
#   'ru',
#   'mystery',
#   'train',
#   '20',
#   '35',
#   'стрингер',
#   'премьера',
#   'режиссёр',
#   'дэн',
#   'гилрой',
#   'сша',
#   '2013',
#   'билет',
#   'outcinema',
#   'ru',
#   'nightcrawler',
#   'найти',
#   'vk',
#   'cc',
#   '8prnty',
#   'сеанс',
#   'сопровождаться',
#   'реклама',
#   'смело',
#   'приходить',
#   '10',
#   'минута',
#   'время',
#   'x',
#   'пропустить',
#   'начало',
#   'фильм'],
#  ['прекрасный',
#   'николь',
#   'кидман',
#   'объектив',
#   'чжун',
#   'линь',
#   'perfect',
#   'magazine',
#   'посмотреть',
#   'прекрасный',
#   'игра',
#   'смочь',
#   'завтра',
#   'показ',
#   'фильм',
#   'ларс',
#   'фон',
#   'триер',
#   'догвилль',
#   '19',
#   '35'],
#  ['среда',
#   '28',
#   'июнь',
#   'имя',
#   'граф',
#   'режиссёр',
#   'являться',
#   'неоспоримый',
#   'гарант',
#   'качество',
#   'сам',
#   'частенько',
#   'писать',
#   'нынешний',
#   'интернет',
#   'это',
#   'смотреть',
#   '14',
#   '30',
#   'дерсу',
#   'узал',
#   'режиссёр',
#   'акир',
#   'куросава',
#   'ссср',
#   'япония',
#   '1975',
#   'билет',
#   'outcinema',
#   'ru',
#   'dersu',
#   'uzala',
#   '17',
#   '10',
#   'дневник',
#   'сельский',
#   'священник',
#   'режиссёр',
#   'робер',
#   'брессон',
#   'франция',
#   '1951',
#   'билет',
#   'outcinema',
#   'ru',
#   'journal',
#   'dun',
#   'cure',
#   'de',
#   'campagne',
#   '19',
#   '35',
#   'догвилль',
#   'режиссёр',
#   'ларс',
#   'фон',
#   'триер',
#   'дания',
#   'сша',
#   '2003',
#   'билет',
#   'outcinema',
#   'ru',
#   'dogville',
#   'найти',
#   'vk',
#   'cc',
#   '8prnty',
#   'сеанс',
#   'сопровождаться',
#   'реклама',
#   'смело',
#   'приходить',
#   '10',
#   'минута',
#   'время',
#   'x',
#   'пропустить',
#   'начало',
#   'фильм'],
#  ['делать',
#   'человек',
#   'который',
#   'сближаться',
#   'желание',
#   'изолироваться',
#   'весь',
#   'внезапно',
#   'исчезать',
#   'вернуть',
#   'пропасть',
#   'радар',
#   'ваш',
#   'слепой',
#   'любовь',
#   'окружающий',
#   'мир',
#   'уравнение',
#   'выбывать',
#   'важный',
#   'переменный',
#   'существовать',
#   'холодный',
#   'тихий',
#   'копенгаген',
#   'сам',
#   'дело',
#   'концептуальный',
#   'картина',
#   'датчанин',
#   'мартин',
#   'сковбьерг',
#   'хороший',
#   'традиция',
#   'бертолуччи',
#   'финчер',
#   'жан',
#   'пьер',
#   'жён',
#   'соединять',
#   'реальный',
#   'мир',
#   'обман',
#   'подсознательный',
#   'этот',
#   'лента',
#   'задавать',
#   'вопрос',
#   'фонтанировать',
#   'экзистенциальный',
#   'раздумье',
#   'однако',
#   'утомлять',
#   'наоборот',
#   'обволакивать',
#   'затягивать',
#   'ментальный',
#   'неонуар',
#   'который',
#   'крутой',
#   'детектив',
#   'жаркий',
#   'перестрелка',
#   'равно',
#   'хватать',
#   'цинизм',
#   'чеховский',
#   'ружьё',
#   'ждать',
#   'показ',
#   'фильм',
#   'копенгаген',
#   'существовать',
#   'cinema',
#   '27',
#   'июнь',
#   '20',
#   '50'],
#  ['вторник',
#   '27',
#   'июнь',
#   'запускать',
#   'кругосветка',
#   'бродить',
#   'черно',
#   'белый',
#   'французский',
#   'столица',
#   'постигать',
#   'семейный',
#   'дрязг',
#   'сердце',
#   'южный',
#   'корея',
#   'наблюдать',
#   'триллер',
#   'развернуться',
#   'декорация',
#   'пасмурный',
#   'датский',
#   'мегаполис',
#   '16',
#   '15',
#   'париж',
#   '13',
#   'й',
#   'округ',
#   'режиссёр',
#   'жак',
#   'одиар',
#   'франция',
#   '2021',
#   'билет',
#   'outcinema',
#   'ru',
#   'les',
#   'olympiades',
#   'paris',
#   '13e',
#   '18',
#   '25',
#   'возвращение',
#   'сеул',
#   'режиссёр',
#   'дэви',
#   'шу',
#   'южный',
#   'корея',
#   '2022',
#   'билет',
#   'outcinema',
#   'ru',
#   'retour',
#   'seoul',
#   '20',
#   '50',
#   'копенгаген',
#   'существовать',
#   'режиссёр',
#   'мартин',
#   'сковбьерг',
#   'дания',
#   '2023',
#   'билет',
#   'outcinema',
#   'ru',
#   'kobenhavn',
#   'findes',
#   'ikke',
#   'найти',
#   'vk',
#   'cc',
#   '8prnty',
#   'сеанс',
#   'сопровождаться',
#   'реклама',
#   'смело',
#   'приходить',
#   '10',
#   'минута',
#   'время',
#   'x',
#   'пропустить',
#   'начало',
#   'фильм'],
#  ['мертвец',
#   '1995',
#   'джим',
#   'джармуш',
#   'черно',
#   'белый',
#   'путешествие',
#   'свет',
#   'компания',
#   'убийца',
#   'поневоле',
#   'мудрый',
#   'индеец',
#   'отправляться',
#   '26',
#   'июнь',
#   '18',
#   '10'],
#  ['понедельник',
#   '26',
#   'июнь',
#   'трио',
#   'великий',
#   'визионер',
#   'разрывать',
#   'шаблон',
#   'демонстрировать',
#   'эталонный',
#   'чистый',
#   'кинематограф',
#   'какой',
#   'либо',
#   'раздражающий',
#   'примесь',
#   '16',
#   '00',
#   'страх',
#   'сцена',
#   'режиссёр',
#   'альфред',
#   'хичкок',
#   'великобритания',
#   '1950',
#   'билет',
#   'outcinema',
#   'ru',
#   'stage',
#   'fright',
#   '18',
#   '10',
#   'мертвец',
#   'режиссёр',
#   'джим',
#   'джармуш',
#   'сша',
#   'германия',
#   '1995',
#   'билет',
#   'outcinema',
#   'ru',
#   'dead',
#   '20',
#   '35',
#   'ностальгия',
#   'режиссёр',
#   'андрей',
#   'тарковский',
#   'ссср',
#   'италия',
#   '1983',
#   'билет',
#   'outcinema',
#   'ru',
#   'nostalghia',
#   'найти',
#   'vk',
#   'cc',
#   '8prnty',
#   'сеанс',
#   'сопровождаться',
#   'реклама',
#   'смело',
#   'приходить',
#   '10',
#   'минута',
#   'время',
#   'x',
#   'пропустить',
#   'начало',
#   'фильм'],
#  ['голова',
#   'ластик',
#   '1977',
#   'твин',
#   'пикс',
#   '1990',
#   '1991',
#   'метастаз',
#   'безумие',
#   'заложить',
#   'фильм',
#   'голова',
#   'ластик',
#   'дебютант',
#   'дэвид',
#   'линч',
#   'отбрасывать',
#   'сомнение',
#   'экран',
#   'изобразить',
#   'нулевой',
#   'уровень',
#   'ад',
#   'выбраться',
#   'который',
#   'невозможно',
#   'застать',
#   'апофеоз',
#   'сюрреализм',
#   'завтра',
#   '18',
#   '25',
#   'наш',
#   'кинотеатр'],
#  ['воскресение',
#   '25',
#   'июнь',
#   'японский',
#   'мультипликация',
#   'самурайский',
#   'детектив',
#   'сюрреалистичный',
#   'американский',
#   'хтоня',
#   'жемчужина',
#   'французский',
#   'кинодвижение',
#   'поэтический',
#   'реалист',
#   '11',
#   '00',
#   'заветный',
#   'желание',
#   'режиссёр',
#   'котаро',
#   'тамур',
#   'япония',
#   '2020',
#   'билет',
#   'outcinema',
#   'ru',
#   'josee',
#   'tora',
#   'sakana',
#   'tachi',
#   '16',
#   '30',
#   'расёмона',
#   'режиссёр',
#   'акир',
#   'куросава',
#   'япония',
#   '1950',
#   'билет',
#   'outcinema',
#   'ru',
#   'rashomon',
#   '18',
#   '25',
#   'голова',
#   'ластик',
#   'режиссёр',
#   'дэвид',
#   'линч',
#   'сша',
#   '1977',
#   'билет',
#   'outcinema',
#   'ru',
#   'earaserhead',
#   '20',
#   '20',
#   'день',
#   'начинаться',
#   'лекция',
#   'обсуждение',
#   'режиссёр',
#   'марсель',
#   'карне',
#   'франция',
#   '1939',
#   'билет',
#   'outcinema',
#   'ru',
#   'le',
#   'jour',
#   'se',
#   'leve',
#   'найти',
#   'vk',
#   'cc',
#   '8prnty',
#   'сеанс',
#   'сопровождаться',
#   'реклама',
#   'смело',
#   'приходить',
#   '10',
#   'минута',
#   'время',
#   'x',
#   'пропустить',
#   'начало',
#   'фильм'],
#  ['море',
#   'знать',
#   'милосердие',
#   'знать',
#   'иной',
#   'власть',
#   'кроме',
#   'свой',
#   'собственный',
#   'мобь',
#   'дик',
#   'белый',
#   'кит',
#   '1851',
#   'герман',
#   'мелвилл',
#   'сегодняшний',
#   'день',
#   'человечество',
#   'изучить',
#   'примерно',
#   '5',
#   'мировой',
#   'океан',
#   'непробиваемый',
#   'толща',
#   'вода',
#   'равно',
#   'достижение',
#   'технический',
#   'прогресс',
#   'наш',
#   'упорство',
#   'колыбель',
#   'человечество',
#   'считать',
#   'наш',
#   'вид',
#   'недостаточно',
#   'развитой',
#   'открывать',
#   'мы',
#   'свой',
#   'самый',
#   'сокровенный',
#   'тайна',
#   'находиться',
#   'глубина',
#   'проникать',
#   'солнечный',
#   'свет',
#   'знать',
#   'лишь',
#   'морской',
#   'обитатель',
#   'король',
#   'который',
#   'являться',
#   'кит',
#   'громадный',
#   'млекопитающее',
#   'чей',
#   'величие',
#   'описываться',
#   'религиозный',
#   'текст',
#   'тысяча',
#   'научный',
#   'труд',
#   'кит',
#   'стража',
#   'планета',
#   'удивительный',
#   'существо',
#   'изучение',
#   'который',
#   'посвятить',
#   'документальный',
#   'фильм',
#   'жан',
#   'альбер',
#   'льёвр',
#   '24',
#   'июнь',
#   'наш',
#   'кинотеатр',
#   'состояться',
#   'показ',
#   'безгранично',
#   'красивый',
#   'крайне',
#   'познавательный',
#   'картина',
#   'сеанс',
#   'начинаться',
#   '11',
#   '00'],
#  ['суббота',
#   '24',
#   'июнь',
#   'созерцание',
#   'главное',
#   'слово',
#   'определять',
#   'объединять',
#   'себя',
#   'фильм',
#   'который',
#   'начинаться',
#   'насыщенный',
#   'выходной',
#   'день',
#   '11',
#   '00',
#   'кит',
#   'стража',
#   'планета',
#   'режиссёр',
#   'жан',
#   'альбер',
#   'льёвр',
#   'франция',
#   '2023',
#   'билет',
#   'outcinema',
#   'ru',
#   'les',
#   'gardiennes',
#   'de',
#   'la',
#   'planete',
#   '12',
#   '50',
#   'сталкер',
#   'режиссёр',
#   'андрей',
#   'тарковский',
#   'ссср',
#   '1979',
#   'билет',
#   'outcinema',
#   'ru',
#   'stalker',
#   '20',
#   '30',
#   'сказка',
#   'туманный',
#   'луна',
#   'дождь',
#   'кино',
#   'лекция',
#   'режиссёр',
#   'кэндзь',
#   'мидзогути',
#   'япония',
#   '1953',
#   'билет',
#   'outcinema',
#   'ru',
#   'ugetsu',
#   'monogatari',
#   'найти',
#   'vk',
#   'cc',
#   '8prnty',
#   'сеанс',
#   'сопровождаться',
#   'реклама',
#   'смело',
#   'приходить',
#   '10',
#   'минута',
#   'время',
#   'x',
#   'пропустить',
#   'начало',
#   'фильм'],
#  ['причина',
#   'смотреть',
#   'фильм',
#   'альфред',
#   'хичкок',
#   'леди',
#   'исчезать',
#   'первый',
#   'причина',
#   'это',
#   'романтический',
#   'элемент',
#   'динамика',
#   'чувство',
#   'ритм',
#   'движение',
#   'поезд',
#   'второй',
#   'это',
#   'очаровательный',
#   'комический',
#   'персонаж',
#   'который',
#   'невероятно',
#   'интересно',
#   'наблюдать',
#   'третий',
#   'стилизовать',
#   'хичкоковский',
#   'саспенс',
#   'использовать',
#   'достижение',
#   'монтаж',
#   'конец',
#   '1930',
#   'х',
#   'убедиться',
#   'весь',
#   'выше',
#   'сказать',
#   'смочь',
#   'завтра',
#   'время',
#   'сеанс',
#   '13',
#   '50'],
#  ['пятница',
#   '23',
#   'июнь',
#   'самый',
#   'время',
#   'самый',
#   'наслаждаться',
#   'классика',
#   'мировой',
#   'кино',
#   'фестивальный',
#   'работа',
#   'многообещающий',
#   'премьера',
#   'дания',
#   '13',
#   '50',
#   'леди',
#   'исчезать',
#   'режиссёр',
#   'альфред',
#   'хичкок',
#   'великобритания',
#   '1938',
#   'билет',
#   'outcinema',
#   'ru',
#   'lady',
#   'vanishes',
#   '15',
#   '50',
#   'жить',
#   'режиссёр',
#   'акир',
#   'куросава',
#   'япония',
#   '1952',
#   'билет',
#   'outcinema',
#   'ru',
#   'ikiru',
#   '18',
#   '40',
#   'париж',
#   '13',
#   'й',
#   'округ',
#   'режиссёр',
#   'жак',
#   'одиар',
#   'франция',
#   '2021',
#   'билет',
#   'outcinema',
#   'ru',
#   'les',
#   'olympiades',
#   'paris',
#   '13e',
#   '20',
#   '50',
#   'копенгаген',
#   'существовать',
#   'премьера',
#   'режиссёр',
#   'мартин',
#   'сковбьерг',
#   'дания',
#   '2023',
#   'билет',
#   'outcinema',
#   'ru',
#   'kobenhavn',
#   'findes',
#   'ikke',
#   'найти',
#   'vk',
#   'cc',
#   '8prnty',
#   'сеанс',
#   'сопровождаться',
#   'реклама',
#   'смело',
#   'приходить',
#   '10',
#   'минута',
#   'время',
#   'x',
#   'пропустить',
#   'начало',
#   'фильм'],
#  ['саундтрек',
#   'лента',
#   'ксавье',
#   'долан',
#   'жизнь',
#   'смерть',
#   'семья',
#   'тщетный',
#   'покаяние'],
#  ['авторский', 'кино', 'telegram', 'https', 'kino', 'culture'],
#  ['кислотный',
#   'дом',
#   'acid',
#   'house',
#   '1998',
#   'режиссёр',
#   'пол',
#   'макгиган',
#   'серия',
#   'рассказ',
#   'ирвин',
#   'уэлш',
#   'acid',
#   'house',
#   '1994',
#   'драма',
#   'комедия',
#   'экранизация',
#   'великобритания',
#   'роль',
#   'стивен',
#   'маккоул',
#   'морис',
#   'роевз',
#   'гарри',
#   'суиня',
#   'дженни',
#   'маккрайндло',
#   'саймон',
#   'вейра',
#   'иэн',
#   'эндрю',
#   'ирвин',
#   'уэлш',
#   'пэт',
#   'стэнтон',
#   'алекс',
#   'хауден',
#   'энни',
#   'луиз',
#   'росс',
#   'фильм',
#   'состоять',
#   'три',
#   'независимый',
#   'часть',
#   'общий',
#   'дело',
#   'грэнтон',
#   'старый',
#   'рохля',
#   'кислотный',
#   'дом',
#   'герой',
#   'первый',
#   'новелла',
#   'предстоять',
#   'побывать',
#   'шкура',
#   'насекомое',
#   'совершенно',
#   'буквально',
#   'слово',
#   'вид',
#   'неблагосклонность',
#   'всевышний',
#   'персонаж',
#   'второй',
#   'история',
#   'вынудить',
#   'столкнуться',
#   'трагикомический',
#   'случаем',
#   'адюльтер',
#   'замыкать',
#   'киноповесть',
#   'невероятный',
#   'галлюциногенный',
#   'трип',
#   'обмен',
#   'тело',
#   'перемещение',
#   'душа',
#   '1998',
#   'год',
#   'фильм',
#   'вызвать',
#   'небывалый',
#   'резонанс',
#   'осудить',
#   'консервативный',
#   'британский',
#   'пресса',
#   'чрезмерно',
#   'унизительный',
#   'обращение',
#   'чувство',
#   'верующий',
#   'трудно',
#   'охарактеризовать',
#   'один',
#   'слово',
#   'один',
#   'выражение',
#   'однако',
#   'критика',
#   'известный',
#   'мера',
#   'удивить',
#   'скупиться',
#   'похвала',
#   'глубина',
#   'философский',
#   'подтекст',
#   'чудовищный',
#   'выброс',
#   'энергия',
#   'форма',
#   'фильм',
#   'культовый',
#   'картина',
#   'правдивый',
#   'рассказывать',
#   'жизнь',
#   'современный',
#   'молодёжь',
#   'бульварный',
#   'пресса',
#   'великобритания',
#   'назвать',
#   'фильм',
#   'отвратительный',
#   'оскорбительный',
#   'изображение',
#   'бог',
#   'матершинник',
#   'сквернослов',
#   'эпизодический',
#   'роль',
#   'уборщик',
#   'раздевалка',
#   'первый',
#   'новелла',
#   'сняться',
#   'ирвин',
#   'уэлш',
#   'хотя',
#   'фильм',
#   'снятой',
#   'английский',
#   'некоторый',
#   'показ',
#   'англоязычный',
#   'страна',
#   'сопровождаться',
#   'субтитр',
#   'сильный',
#   'шотландский',
#   'акцент',
#   'рейтинг',
#   'imdb',
#   '6',
#   '30',
#   'кинопоиск',
#   '6',
#   '76'],
#  ['паскуалиный',
#   'семь',
#   'красотка',
#   'pasqualino',
#   'settebellezze',
#   '1975',
#   'режиссёр',
#   'лина',
#   'вертмюллер',
#   'драма',
#   'комедия',
#   'италия',
#   'роль',
#   'джанкарло',
#   'джанниня',
#   'фернандо',
#   'рей',
#   'ширлить',
#   'столера',
#   'елена',
#   'фьор',
#   'пьеро',
#   'ди',
#   'иорио',
#   'энцо',
#   'витала',
#   'роберто',
#   'херлицк',
#   'лучио',
#   'амелио',
#   'выжить',
#   'готовый',
#   'говорить',
#   'паскуалиный',
#   'который',
#   'прозвать',
#   'семь',
#   'красотка',
#   'семь',
#   'сестра',
#   'отнюдь',
#   'красавица',
#   'действие',
#   'картина',
#   'разбиваться',
#   'параллельный',
#   'пласт',
#   'жизнь',
#   'война',
#   'жизнь',
#   'концлагерь',
#   'попасть',
#   'дезертировать',
#   'восточный',
#   'фронт',
#   'рейтинг',
#   'imdb',
#   '8',
#   '00',
#   'кинопоиск',
#   '7',
#   '74'],
#  ['наш',
#   'хороший',
#   'кредитка',
#   'кредитка',
#   'нужно',
#   'платить',
#   'комиссия',
#   'перевод',
#   'карта',
#   'любой',
#   'банк',
#   'отправлять',
#   '100',
#   '000',
#   '₽',
#   'месяц',
#   'процент',
#   'ещё',
#   'лимит',
#   '700',
#   '000',
#   '₽',
#   '120',
#   'день',
#   'кэшбэк',
#   '30',
#   'бонус',
#   'оформить',
#   'такой',
#   'ссылка',
#   'https',
#   'vk',
#   'tinkoff',
#   'ru',
#   'cc',
#   'free100'],
#  ['наследство',
#   'arven',
#   '2003',
#   'русый',
#   'субтитр',
#   'режиссёр',
#   'пер',
#   'флю',
#   'драма',
#   'дания',
#   'швеция',
#   'норвегия',
#   'великобритания',
#   'роль',
#   'ульрих',
#   'томсный',
#   'лайза',
#   'верлиндер',
#   'гит',
#   'нёрбь',
#   'карина',
#   'скандс',
#   'ларс',
#   'брюгманна',
#   'петер',
#   'стейный',
#   'диана',
#   'аксельсный',
#   'еспереть',
#   'кристенсный',
#   'четыре',
#   'год',
#   'назад',
#   'кристоффера',
#   'покинуть',
#   'семейный',
#   'сталелитейный',
#   'бизнес',
#   'переехать',
#   'другой',
#   'страна',
#   'свой',
#   'ресторан',
#   'жена',
#   'актриса',
#   'наступать',
#   'момент',
#   'непредвиденный',
#   'обстоятельство',
#   'вынуждать',
#   'кристоффер',
#   'бросить',
#   'продолжить',
#   'дело',
#   'свой',
#   'отец',
#   'сан',
#   'себастьян',
#   '2003',
#   'хороший',
#   'сценарий',
#   'рейтинг',
#   'imdb',
#   '7',
#   '30',
#   'кинопоиск',
#   '6',
#   '46'],
#  ['фонтан',
#   '1988',
#   'режиссёр',
#   'юрий',
#   'мамин',
#   'комедия',
#   'ссср',
#   'роль',
#   'сергей',
#   'дрейден',
#   'виктор',
#   'михайлов',
#   'жанна',
#   'керимтаев',
#   'асанкул',
#   'куттубаев',
#   'нина',
#   'усатов',
#   'алексей',
#   'заливалов',
#   'анатолий',
#   'калмыков',
#   'людмила',
#   'самохвалов',
#   'николай',
#   'траньковы',
#   'любовь',
#   'аркус',
#   'действие',
#   'фильм',
#   'происходить',
#   'время',
#   'перестройка',
#   'ссср',
#   'ленинград',
#   'холодный',
#   'зимой',
#   'герой',
#   'фильм',
#   'жилец',
#   'обычный',
#   'дом',
#   'который',
#   'развалиться',
#   'героический',
#   'усилие',
#   'главное',
#   'инженер',
#   'жэу',
#   'лагутин',
#   'лифт',
#   'давно',
#   'работать',
#   'капитальный',
#   'стена',
#   'проходить',
#   'опасный',
#   'трещина',
#   'крыша',
#   'просесть',
#   'тяжесть',
#   'снег',
#   'дом',
#   'продолжать',
#   'держаться',
#   'буквально',
#   'плечо',
#   'подвижник',
#   'лагутин',
#   'рейтинг',
#   'imdb',
#   '7',
#   '30',
#   'кинопоиск',
#   '7',
#   '83'],
#  ['диско',
#   'ядерный',
#   'война',
#   'disko',
#   'ja',
#   'tuumasõda',
#   '2009',
#   'режиссёр',
#   'яак',
#   'кильмить',
#   'документальный',
#   'эстония',
#   'финляндия',
#   'житель',
#   'социалистический',
#   'эстония',
#   'находить',
#   'спасение',
#   'серость',
#   'будни',
#   'настраивать',
#   'антенна',
#   'свой',
#   'телевизор',
#   'волна',
#   'финский',
#   'телевидение',
#   'демонстрировать',
#   'столь',
#   'желанный',
#   'образ',
#   'загнивать',
#   'капитализм',
#   'информационный',
#   'война',
#   'тоталитарный',
#   'режим',
#   'проигрывать',
#   'рейтинг',
#   'imdb',
#   '7',
#   '60',
#   'кинопоиск'],
#  ['мудрость',
#   'la',
#   'sapienza',
#   '2014',
#   'русый',
#   'субтитр',
#   'режиссёр',
#   'эжен',
#   'грин',
#   'драма',
#   'франция',
#   'италия',
#   'роль',
#   'фабрицио',
#   'ронджон',
#   'кристель',
#   'людовико',
#   'суччо',
#   'арианна',
#   'настро',
#   'знаменитый',
#   'швейцарский',
#   'архитектор',
#   'александр',
#   'шмидт',
#   'специалист',
#   'франческо',
#   'борроминь',
#   'переживать',
#   'кризис',
#   'верный',
#   'тот',
#   'профессиональный',
#   'принцип',
#   'который',
#   'долго',
#   'исповедовать',
#   'путешествовать',
#   'собор',
#   'турин',
#   'рим',
#   'показывать',
#   'молодой',
#   'друг',
#   'который',
#   'собираться',
#   'учиться',
#   'архитектура',
#   'супруг',
#   'оставаться',
#   'это',
#   'время',
#   'стреза',
#   'вместе',
#   'сестра',
#   'юноша',
#   'пытаться',
#   'примириться',
#   'прошлое',
#   'найти',
#   'гармония',
#   'настоящий',
#   'рейтинг',
#   'imdb',
#   '6',
#   '50',
#   'кинопоиск',
#   '7',
#   '25'],
#  ['донни',
#   'дарко',
#   'donnie',
#   'darko',
#   '2001',
#   'режиссёр',
#   'ричард',
#   'келли',
#   'фантастика',
#   'драма',
#   'сша',
#   'роль',
#   'джейк',
#   'джилленхол',
#   'джена',
#   'мэлоун',
#   'мэгга',
#   'джилленхол',
#   'мэри',
#   'макдоннелла',
#   'холмс',
#   'осборн',
#   'патрик',
#   'суэйзи',
#   'ноа',
#   'уайли',
#   'дрю',
#   'бэрримор',
#   'джеймс',
#   'дювал',
#   'свой',
#   '16',
#   'год',
#   'старшеклассник',
#   'донни',
#   'знать',
#   'такой',
#   'смерть',
#   'несчастный',
#   'случай',
#   'едва',
#   'стоить',
#   'жизнь',
#   'донни',
#   'открывать',
#   'способность',
#   'изменять',
#   'время',
#   'судьба',
#   'перемена',
#   'случиться',
#   'пугать',
#   'окружать',
#   'родитель',
#   'сестра',
#   'учитель',
#   'друг',
#   'любимый',
#   'девушка',
#   'мэгга',
#   'джилленхол',
#   'сестра',
#   'джейк',
#   'джилленхол',
#   'играть',
#   'сестра',
#   'донни',
#   'фильм',
#   'попасть',
#   'съёмочный',
#   'площадка',
#   'благодаря',
#   'сцена',
#   'безумный',
#   'сесиль',
#   'б',
#   '2000',
#   'который',
#   'очень',
#   'понравиться',
#   'ричард',
#   'келли',
#   'изначально',
#   'донни',
#   'гретхен',
#   'должный',
#   'смотреть',
#   'кинотеатр',
#   'c',
#   'h',
#   'u',
#   '1984',
#   'однако',
#   'возникнуть',
#   'сложность',
#   'определение',
#   'владелец',
#   'право',
#   'данный',
#   'фильм',
#   'поэтому',
#   'сэм',
#   'рэнять',
#   'предложить',
#   'бесплатно',
#   'воспользоваться',
#   'зловещий',
#   'мертвец',
#   '1981',
#   'вечеринка',
#   'заметить',
#   'прыгать',
#   'батут',
#   'маска',
#   'рональд',
#   'рейган',
#   'это',
#   '–',
#   'ссылка',
#   'фотография',
#   'журналист',
#   'хантер',
#   'томпсон',
#   'одетый',
#   'маска',
#   'рейган',
#   'прыгать',
#   'батут',
#   'оригинальный',
#   'постер',
#   'фильм',
#   'содержать',
#   'надпись',
#   'выполнить',
#   'шрифт',
#   'стиль',
#   'арабский',
#   'язык',
#   'выход',
#   'фильм',
#   'видео',
#   'который',
#   'состояться',
#   'событие',
#   '11',
#   'сентябрь',
#   '2001',
#   'год',
#   'шрифт',
#   'заменить',
#   'дружелюбный',
#   'times',
#   'new',
#   'roman',
#   'режиссёрский',
#   'версия',
#   'фильм',
#   'изготовить',
#   '9',
#   'день',
#   'длинный',
#   'обычный',
#   '20',
#   'минута',
#   'обычный',
#   'версия',
#   'исключить',
#   'несколько',
#   'сцена',
#   'некоторый',
#   'который',
#   'являться',
#   'ключевой',
#   'понимание',
#   'сюжет',
#   'например',
#   'выдержка',
#   'цитата',
#   'книга',
#   'философия',
#   'путешествие',
#   'время',
#   'роберт',
#   'сперроу',
#   'который',
#   'пронизать',
#   'весь',
#   'сюжет',
#   'сцена',
#   'диалог',
#   'донни',
#   'психотерапевт',
#   'последний',
#   'говорить',
#   'таблетка',
#   'прописать',
#   'режиссёрский',
#   'версия',
#   'выйти',
#   '1001',
#   'день',
#   'театральный',
#   'рейтинг',
#   'imdb',
#   '8',
#   '10',
#   'кинопоиск',
#   '7',
#   '61'],
#  ['девушка',
#   'смерть',
#   '2012',
#   'режиссёр',
#   'йос',
#   'стеллинга',
#   'драма',
#   'россия',
#   'нидерланды',
#   'германия',
#   'роль',
#   'леонид',
#   'бичевино',
#   'сильвия',
#   'хукс',
#   'сергей',
#   'маковецкий',
#   'дитер',
#   'халлервордный',
#   'рената',
#   'литвинов',
#   'светлана',
#   'светличный',
#   'анри',
#   'гарсен',
#   'йоост',
#   'спийкерс',
#   'джим',
#   'ван',
#   'дер',
#   'вауд',
#   'дмитрий',
#   'брауэр',
#   'николай',
#   'возвращаться',
#   'забросить',
#   'отель',
#   'пятьдесят',
#   'год',
#   'назад',
#   'встретить',
#   'единственный',
#   'любовь',
#   'охватить',
#   'воспоминание',
#   'заново',
#   'переживать',
#   'трагический',
#   'история',
#   'свой',
#   'юность',
#   'являться',
#   'одновременно',
#   'рассказчик',
#   'герой',
#   'повествование',
#   'действие',
#   'разворачиваться',
#   'три',
#   'временной',
#   'пласт',
#   'конец',
#   'xix',
#   'век',
#   'время',
#   'юность',
#   'герой',
#   'пятидесятый',
#   'год',
#   'xx',
#   'век',
#   'наш',
#   'день',
#   'рейтинг',
#   'imdb',
#   '6',
#   '40',
#   'кинопоиск',
#   '6',
#   '80'],
#  ['вздёрнуть',
#   'высоко',
#   'hang',
#   'em',
#   'high',
#   '1968',
#   'режиссёр',
#   'тед',
#   'пост',
#   'вестерн',
#   'сша',
#   'роль',
#   'клинт',
#   'иствуд',
#   'ингера',
#   'стивенс',
#   'эда',
#   'бегнуть',
#   'пэт',
#   'хингл',
#   'бен',
#   'джонсон',
#   'чарльз',
#   'макгроу',
#   'рута',
#   'уайт',
#   'брюс',
#   'дёрн',
#   'алан',
#   'хейл',
#   'мл',
#   'джеда',
#   'купер',
#   'ошибочно',
#   'принять',
#   'грабитель',
#   'убийца',
#   'угнать',
#   'чужой',
#   'скот',
#   'продажный',
#   'судья',
#   'уилсон',
#   'приговорить',
#   'герой',
#   'суд',
#   'линч',
#   'повешение',
#   'раненый',
#   'ковбой',
#   'чудом',
#   'остаться',
#   'живой',
#   'местный',
#   'шериф',
#   'подрезать',
#   'веревку…',
#   'первый',
#   'фильм',
#   'спродюсировать',
#   'компания',
#   'клинт',
#   'иствуд',
#   'malpaso',
#   'company',
#   'клинт',
#   'иствуд',
#   'отказаться',
#   'съёмка',
#   'фильм',
#   'золото',
#   'маккен',
#   'сняться',
#   'фильм',
#   'рейтинг',
#   'imdb',
#   '7',
#   '00',
#   'кинопоиск',
#   '7',
#   '20'],
#  ['засуха',
#   'siccità',
#   '2022',
#   'режиссёр',
#   'паоло',
#   'вирдзь',
#   'драма',
#   'комедия',
#   'италия',
#   'роль',
#   'сильвио',
#   'орландо',
#   'валерио',
#   'мастандреа',
#   'элена',
#   'льетти',
#   'томмазо',
#   'раньо',
#   'клаудия',
#   'пандольфи',
#   'виничио',
#   'маркиони',
#   'моника',
#   'беллуччи',
#   'рим',
#   'год',
#   'дождь',
#   'поскольку',
#   'засуха',
#   'становиться',
#   'сильный',
#   'каждый',
#   'день',
#   'правило',
#   'обычай',
#   'общество',
#   'меняться',
#   'венецианский',
#   'кинофестиваль',
#   '2022',
#   'премия',
#   'пазинетти',
#   'хороший',
#   'фильм',
#   'премия',
#   'soundtrack',
#   'stars',
#   'хороший',
#   'саундтрек',
#   'версия',
#   'кинокритик',
#   'рейтинг',
#   'imdb',
#   '6',
#   '30',
#   'кинопоиск'],
#  ['одинокий',
#   'сердце',
#   'さ',
#   'び',
#   'し',
#   'ん',
#   'ぼ',
#   'う',
#   '1985',
#   'русый',
#   'субтитр',
#   'режиссёр',
#   'нобухико',
#   'обаясь',
#   'фэнтези',
#   'комедия',
#   'япония',
#   'роль',
#   'ясукий',
#   'томит',
#   'тосинорь',
#   'омь',
#   'юмико',
#   'фудзита',
#   'нэндзь',
#   'кобаясь',
#   'макото',
#   'сато',
#   'итток',
#   'кисибэ',
#   'рис',
#   'акигава',
#   'нао',
#   'асука',
#   'одинокий',
#   'старшеклассник',
#   'хирок',
#   'влюбить',
#   'один',
#   'девушка',
#   'который',
#   'наблюдать',
#   'свой',
#   'объектив',
#   'внезапный',
#   'образ',
#   'зов',
#   'приходить',
#   'другой',
#   'странный',
#   'девушка',
#   'реальный',
#   'плод',
#   'фантазия',
#   'рейтинг',
#   'imdb',
#   '7',
#   '20',
#   'кинопоиск'],
#  ['псевдёжа',
#   'симулякр',
#   '2014',
#   'режиссёр',
#   'наталия',
#   'мещанинов',
#   'документальный',
#   'россия',
#   'кадр',
#   'александр',
#   'бренер',
#   'владислав',
#   'мамышева',
#   'анатолий',
#   'осмоловский',
#   'олег',
#   'кулик',
#   'константин',
#   'звездочёт',
#   'жаргонный',
#   'слово',
#   'псевдёжа',
#   'являться',
#   'вольный',
#   'перевод',
#   'философский',
#   'термин',
#   'симулякр',
#   'означать',
#   'знак',
#   'иметь',
#   'означать',
#   'объект',
#   'реальность',
#   'герой',
#   'фильм',
#   'пытаться',
#   'понять',
#   'являться',
#   'это',
#   'самый',
#   'псевдёж',
#   'деятельность',
#   'окружающий',
#   'коллектив',
#   'молодой',
#   'актёр',
#   'начинать',
#   'работать',
#   'спектакль',
#   'который',
#   'посвятить',
#   'художник',
#   'концептуалист',
#   'герой',
#   '90',
#   'х',
#   'год',
#   'ход',
#   'работа',
#   'два',
#   'творческий',
#   'группа',
#   'постоянно',
#   'сталкиваться',
#   'каждый',
#   'встреча',
#   'актёр',
#   'художник',
#   'нарасти',
#   'взаимный',
#   'раздражение',
#   'рейтинг',
#   'imdb',
#   'кинопоиск'],
#  ['сердце',
#   '–',
#   'это',
#   'тёмный',
#   'лес',
#   'herz',
#   'dunkler',
#   'wald',
#   '2007',
#   'русый',
#   'субтитр',
#   'режиссёр',
#   'николетта',
#   'кребица',
#   'драма',
#   'германия',
#   'роль',
#   'нина',
#   'хосс',
#   'девид',
#   'штрисовый',
#   'bella',
#   'brunnet',
#   'клоэ',
#   'брюнна',
#   'франциска',
#   'петереть',
#   'история',
#   'семья',
#   'мария',
#   'томас',
#   'однажды',
#   'мария',
#   'узнать',
#   'муж',
#   'вести',
#   'двойной',
#   'жизнь',
#   'иметь',
#   'второй',
#   'семья',
#   'это',
#   'повергать',
#   'шок',
#   'мария',
#   'ревновать',
#   'свой',
#   'муж',
#   'медея',
#   'считать',
#   'муж',
#   'предать',
#   'ее…',
#   'рейтинг',
#   'imdb',
#   '6',
#   '50',
#   'кинопоиск',
#   '6',
#   '72'],
#  ['мечта',
#   'кассандра',
#   'cassandra’s',
#   'dream',
#   '2007',
#   'режиссёр',
#   'вудить',
#   'аллен',
#   'триллер',
#   'драма',
#   'сша',
#   'великобритания',
#   'франция',
#   'роль',
#   'юэн',
#   'макгрегор',
#   'колин',
#   'фаррелла',
#   'хейль',
#   'этвелла',
#   'салли',
#   'хокинс',
#   'уилкинсон',
#   'питер',
#   'хьюго',
#   'дэйль',
#   'джон',
#   'бенфилд',
#   'клэр',
#   'хиггинс',
#   'эшли',
#   'мадеква',
#   'брат',
#   'терри',
#   'иена',
#   'ребёнок',
#   'очень',
#   'богатый',
#   'родитель',
#   'также',
#   'постоянно',
#   'испытывать',
#   'нехватка',
#   'деньга',
#   'каждый',
#   'зарабатывать',
#   'свой',
#   'терри',
#   'игра',
#   'карта',
#   'ставка',
#   'собачий',
#   'бега',
#   'спокойный',
#   'рационально',
#   'мыслящий',
#   'иена',
#   'пытаться',
#   'пробить',
#   'дорога',
#   'мир',
#   'инвестиционный',
#   'бизнес',
#   'однако',
#   'другой',
#   'хватать',
#   'удача',
#   'стартовый',
#   'капитал',
#   'обеспечить',
#   'свой',
#   'нужда',
#   'помощь',
#   'семья',
#   'часто',
#   'приходить',
#   'дядюшка',
#   'ховард',
#   'успешный',
#   'владелец',
#   'несколько',
#   'клиника',
#   'брат',
#   'обращаться',
#   'он',
#   'помощь',
#   'рейтинг',
#   'imdb',
#   '6',
#   '70',
#   'кинопоиск',
#   '7',
#   '01'],
#  ['молодой', 'автор', 'кино'],
#  ['независимый',
#   'интернет',
#   'журнал',
#   'кинокультура',
#   'наш',
#   'миссия',
#   'публиковать',
#   'продвигать',
#   'молодой',
#   'автор',
#   'который',
#   'любить',
#   'уметь',
#   'писать',
#   'кино',
#   'рада',
#   'новый',
#   'автор',
#   'поэтому',
#   'сделать',
#   'отдельный',
#   'анкета',
#   'соискатель',
#   'найти',
#   'ссылка',
#   'cinetexts',
#   'ru',
#   'author',
#   'важно',
#   'заявка',
#   'проверяться',
#   'конец',
#   'неделя',
#   'тег',
#   'news',
#   'cinetexts',
#   'reviews',
#   'cinetexts',
#   'essay',
#   'cinetexts',
#   'lists',
#   'cinetexts',
#   'directors',
#   'cinetexts',
#   'articles',
#   'cinetexts',
#   'games',
#   'cinetexts'],
#  ['магия',
#   'число',
#   '20',
#   '000',
#   'hardcore',
#   'members',
#   'вдохновлять',
#   'нью',
#   'йоркский',
#   'бандит',
#   'бунт',
#   'авторитет',
#   'сайрусый',
#   'завязка',
#   'воин',
#   '1979',
#   'го',
#   '20',
#   '000',
#   'лье',
#   'вода',
#   'авантюрный',
#   'роман',
#   'жюля',
#   'верный',
#   'который',
#   'экранизировать',
#   'десятка',
#   'это',
#   'явно',
#   'предел',
#   '20',
#   '000',
#   'евро',
#   'довольно',
#   'скромный',
#   'бюджет',
#   'французский',
#   'байопик',
#   'одиссея',
#   'жизнь',
#   'океанограф',
#   'жак',
#   'ива',
#   'кусто',
#   '20',
#   '000',
#   'день',
#   'земля',
#   'документальный',
#   'фильм',
#   '24',
#   'часы',
#   'жизнь',
#   'безбашенный',
#   'австралийский',
#   'рокер',
#   'ник',
#   'кейв',
#   '20',
#   '000',
#   'это',
#   'число',
#   'подписчик',
#   'сообщество',
#   'журнал',
#   'кинотекст',
#   'vk',
#   'спасибо',
#   'замечательный',
#   'остальной',
#   'продолжать',
#   'работа',
#   'впереди',
#   'немало',
#   'хороший',
#   'кино',
#   'следствие',
#   'контент',
#   'наш',
#   'команда',
#   'скоро',
#   'увидеться',
#   'услышаться',
#   'считаемся😎🤘',
#   'p',
#   'подписать',
#   'наш',
#   'telegram',
#   'https',
#   'cinetexts',
#   'самый',
#   'время',
#   'это',
#   'сделать',
#   'красоваться',
#   'грациозный',
#   'гордый',
#   'циферка',
#   '20',
#   '000'],
#  ['мощный',
#   'выстрел',
#   'дробовик',
#   'грубый',
#   'джести',
#   'челюсть',
#   'круто',
#   'сварить',
#   'фильм',
#   'стивен',
#   'крэйга',
#   'залера',
#   'костяной',
#   'томагавк',
#   '2015',
#   'драка',
#   'блок',
#   '99',
#   '2017',
#   'закатать',
#   'асфальт',
#   '2018'],
#  ['200', 'метр', '2020', 'реж', 'амин', 'найф'],
#  ['документальный',
#   'творчество',
#   'вить',
#   'вендёрса',
#   'странствовать',
#   'наблюдатель',
#   'статья',
#   'катерина',
#   'кукушкин',
#   'стремиться',
#   'догнать',
#   'рассмотреть',
#   'описать',
#   'подноготная',
#   'тот',
#   'картина',
#   'знаменитый',
#   'немецкий',
#   'режиссёр',
#   'который',
#   'рассказывать',
#   'вымышленный',
#   'история',
#   'транслировать',
#   'жизнь',
#   'вполне',
#   'реальный',
#   'человек',
#   'читать',
#   'статья',
#   'cinetexts',
#   'ru',
#   'wim',
#   'wenders',
#   'doc',
#   'документальный',
#   'фильм',
#   'вить',
#   'вендёрса',
#   'склонный',
#   'эссеистический',
#   'подход',
#   'изображение',
#   'действительность',
#   'иначе',
#   'говорить',
#   'режиссёр',
#   'делать',
#   'попытка',
#   'добиться',
#   'недосягаемый',
#   'реальность',
#   'кинематограф',
#   'недосягаемость',
#   'создатель',
#   'небо',
#   'берлин',
#   'чувствовать',
#   'способ',
#   'изображение',
#   'реальность',
#   'вендёрса',
#   'самый',
#   'честный',
#   'признать',
#   'субъективность',
#   'рассказать',
#   'история',
#   'articles',
#   'cinetexts'],
#  ['эддингтон',
#   'ари',
#   'астер',
#   'первый',
#   'подробность',
#   'автор',
#   'реинкарнация',
#   'солнцестояние',
#   'недавний',
#   'сюрреалистичный',
#   'опус',
#   'страх',
#   'бо',
#   'рассказать',
#   'работать',
#   'новый',
#   'проект',
#   'нуарный',
#   'вестерн',
#   'заголовок',
#   'эддингтон',
#   'режиссёр',
#   'подметить',
#   'фильм',
#   'являть',
#   'себя',
#   'ансамблевый',
#   'комедия',
#   'действие',
#   'который',
#   'развернуться',
#   'разгар',
#   'пандемия',
#   'коронавирус',
#   'постоянный',
#   'оператор',
#   'астер',
#   'павел',
#   'погоржельский',
#   'намекнуть',
#   'съёмка',
#   'картина',
#   'стартовать',
#   'это',
#   'лето',
#   'news',
#   'cinetexts'],
#  ['девять',
#   'семь',
#   'семь',
#   '2006',
#   'режиссёр',
#   'николай',
#   'хомерик',
#   'оператор',
#   'алишер',
#   'хамидходжай'],
#  ['последний',
#   'работа',
#   'великий',
#   'мастер',
#   'сарабанда',
#   'saraband',
#   '2003',
#   'режиссёр',
#   'ингмара',
#   'бергман'],
#  ['секс',
#   'насилие',
#   'такой',
#   'поколение',
#   'игра',
#   'doom',
#   'doom',
#   'generation',
#   'реж',
#   'грегга',
#   'арак',
#   '1995'],
#  ['николас',
#   'виндинга',
#   'рефна',
#   'детский',
#   'книжка',
#   'датчанин',
#   'который',
#   'обязать',
#   'появление',
#   'дилер',
#   'драйв',
#   'неоновый',
#   'демон',
#   'близкий',
#   'будущее',
#   'адаптировать',
#   'малый',
#   'экран',
#   'серия',
#   'детский',
#   'детектив',
#   'великолепный',
#   'пятёрка',
#   'проза',
#   'англичанка',
#   'энида',
#   'блайтон',
#   'группа',
#   'подросток',
#   'расследовать',
#   'разношёрстный',
#   'преступление',
#   'дебютировать',
#   '1940',
#   'х',
#   'обрести',
#   'бешеный',
#   'популярность',
#   'настолько',
#   'сильно',
#   'похождение',
#   'маленький',
#   'сыщик',
#   'приглянуться',
#   'публика',
#   'весь',
#   'мир',
#   'вместо',
#   'запланировать',
#   'восемь',
#   'книга',
#   'блайтон',
#   'расщедриться',
#   'целый',
#   '22',
#   'произведение',
#   'серия',
#   'великолепный',
#   'пятёрка',
#   'экранизация',
#   'патронаж',
#   'рефна',
#   'выйти',
#   'канал',
#   'bbc',
#   'именно',
#   'знать',
#   'известно',
#   'съёмка',
#   'сериал',
#   'стартовать',
#   'англия',
#   'датский',
#   'режиссёр',
#   'выступать',
#   'исполнительный',
#   'продюсер',
#   'проект',
#   'функция',
#   'постановщик',
#   'возложить',
#   'тим',
#   'киркбить',
#   'руководить',
#   'производство',
#   'сериал',
#   'дрянь',
#   'фиби',
#   'уоллера',
#   'бридж',
#   'news',
#   'cinetexts'],
#  ['оригинальный',
#   'англоязычный',
#   'название',
#   'фильм',
#   'война',
#   'супруг',
#   'роуз',
#   '1989',
#   'год',
#   'выпуск',
#   'roses',
#   'очевидный',
#   'намёк',
#   'давнишний',
#   'феодальный',
#   'междоусобица',
#   'войти',
#   'история',
#   'война',
#   'ала',
#   'белый',
#   'роза',
#   'оказаться',
#   'грызня',
#   'заковать',
#   'лата',
#   'аристократ',
#   'бракоразводный',
#   'процесс',
#   'гораздо',
#   'общий',
#   'мочь',
#   'подумать',
#   'любовь',
#   'война',
#   'средство',
#   'хороший',
#   'однако',
#   'подразумевать',
#   'слово',
#   'любовь',
#   '17',
#   'ти',
#   'год',
#   'семейный',
#   'жизнь',
#   'либо',
#   'эволюционировать',
#   'крепкий',
#   'сотрудничество',
#   'либо',
#   'оборачиваться',
#   'лютый',
#   'ненависть',
#   'третий',
#   'дать',
#   'война',
#   'супруг',
#   'роуз',
#   'рассматривать',
#   'вариант',
#   'ненависть',
#   'который',
#   'выливаться',
#   'сначала',
#   'тягучий',
#   'многое',
#   'нудный',
#   'обмен',
#   'жёлчь',
#   'супруг',
#   'исполнение',
#   'майкл',
#   'дуглас',
#   'кэтлина',
#   'тернер',
#   'поздний',
#   'перерастать',
#   'мясорубка',
#   'кровавый',
#   'баня',
#   'заправский',
#   'слэшер',
#   'фильм',
#   'увидеть',
#   'однако',
#   'инфантильный',
#   'бытовой',
#   'апокалипсис',
#   'ля',
#   'дом',
#   'лента',
#   'дэнни',
#   'девить',
#   'пахнуть',
#   'знаменитый',
#   'комик',
#   'срежиссировать',
#   'картина',
#   'сыграть',
#   'роль',
#   'юрист',
#   'отговаривать',
#   'молодой',
#   'пара',
#   'развод',
#   'рассказывать',
#   'трагический',
#   'судьба',
#   'чета',
#   'роузов',
#   'война',
#   'супруг',
#   'роуз',
#   'аритмичный',
#   'взрывоопасный',
#   'чёрный',
#   'комедия',
#   'который',
#   'натурально',
#   'отравлять',
#   'зритель',
#   'сковать',
#   'вялотекущий',
#   'действие',
#   'лишь',
#   'прекрасный',
#   'момент',
#   'резко',
#   'ошарашить',
#   'жёсткий',
#   'бескомпромиссный',
#   'развязка',
#   'прибавить',
#   'этот',
#   'раскатистый',
#   'актёрский',
#   'перформанс',
#   'получить',
#   'отличный',
#   'фильм',
#   'насколько',
#   'зыбка',
#   'материя',
#   'семейный',
#   'благополучие'],
#  ['вступительный',
#   'титр',
#   'фильм',
#   'пол',
#   'томас',
#   'андерсон',
#   'мастер',
#   '2012',
#   'врождённый',
#   'порка',
#   '2014',
#   'призрачный',
#   'нить',
#   '2017',
#   'лакричный',
#   'пицца',
#   '2021'],
#  ['кристина', 'ребёнок', 'станция', 'зоо', '1981', 'реж', 'уля', 'эдель'],
#  ['пугать', 'scarecrow', '1973', 'режиссёр', 'джерри', 'шацберг'],
#  ['спасение', 'salvation', 'реж', 'кристиан', 'левринг', '2014'],
#  ['трибить',
#   'операторский',
#   'находка',
#   'фильм',
#   'альфред',
#   'хичкок',
#   'видео',
#   'adyfilk',
#   'источник',
#   'youtu',
#   'lj1z8m7bfgm'],
#  ['синематека', 'искусство', 'кино'],
#  ['проект',
#   'синематека',
#   'искусство',
#   'кино',
#   '–',
#   'это',
#   'цикл',
#   'кинопоказ',
#   'сопровождать',
#   'лекция',
#   'организовать',
#   'журнал',
#   'искусство',
#   'кино',
#   'цель',
#   'проект',
#   '–',
#   'возвращение',
#   'любитель',
#   'авторский',
#   'кинематограф',
#   'дискуссия',
#   'просмотр',
#   'кинозал',
#   'классика',
#   'мировой',
#   'кино',
#   'авангардный',
#   'европейский',
#   'азиатский',
#   'режиссёр',
#   'независимый',
#   'американский',
#   'хороший',
#   'российский',
#   'кино',
#   '–',
#   'всё',
#   'это',
#   'показать',
#   'обсудить',
#   'зрительный',
#   'зал',
#   'кинотеатр',
#   'весь',
#   'страна',
#   'каждый',
#   'сеанс',
#   'проходить',
#   'лекция',
#   'ведущий',
#   'кинокритик',
#   'издание',
#   'который',
#   'ввести',
#   'зритель',
#   'контекст',
#   'помочь',
#   'полно',
#   'увидеть',
#   'режиссёрский',
#   'замысел'],
#  ['журнал',
#   'искусство',
#   'кино',
#   'представлять',
#   'онлайн',
#   'премьера',
#   'первый',
#   'серия',
#   'документальный',
#   'фильм',
#   'история',
#   'российский',
#   'кино',
#   'рождение',
#   'миф',
#   'https',
#   'youtu',
#   '5zlulopdctk',
#   'первый',
#   'эпизод',
#   'речь',
#   'идти',
#   'появление',
#   'развитие',
#   'кинематограф',
#   'дореволюционный',
#   'россия',
#   'рождение',
#   'открытие',
#   'советский',
#   'кино',
#   '20',
#   'х',
#   'приход',
#   'звук',
#   'центр',
#   'пионер',
#   'отечественный',
#   'кино',
#   'вера',
#   'холодный',
#   'иван',
#   'мозжухина',
#   'лев',
#   'кулешов',
#   'всеволод',
#   'пудовкин',
#   'дзиг',
#   'вертов',
#   'сергей',
#   'эйзенштейн',
#   'другой',
#   'наш',
#   'эксперт',
#   'антон',
#   'долина',
#   'тамара',
#   'эйдельман',
#   'андрей',
#   'звягинцев',
#   'александр',
#   'роднянский',
#   'алексей',
#   'айга',
#   'зара',
#   'абдуллаев',
#   'елена',
#   'стишов',
#   'станислав',
#   'дединский',
#   'наталья',
#   'рябчиковый',
#   'наталья',
#   'нусиновый',
#   'другой',
#   'делиться',
#   'свой',
#   'наблюдение',
#   'первый',
#   'открытие',
#   'российский',
#   'советский',
#   'киноязык',
#   'второй',
#   'эпизод',
#   'документальный',
#   'лента',
#   'выйти',
#   '17',
#   'март',
#   'рассказать',
#   'бурный',
#   'развитие',
#   'советский',
#   'кинематограф',
#   'лента',
#   'чапаев',
#   'смерть',
#   'сталин',
#   'рф',
#   'объявить',
#   'иностранный',
#   'агент'],
#  ['чапаев',
#   'смерть',
#   'сталин',
#   'журнал',
#   'искусство',
#   'кино',
#   'представлять',
#   'онлайн',
#   'премьера',
#   'второй',
#   'серия',
#   'документальный',
#   'фильм',
#   'история',
#   'российский',
#   'кино',
#   'рождение',
#   'миф',
#   'второй',
#   'эпизод',
#   'сфокусировать',
#   'развитие',
#   'кинематограф',
#   'ранний',
#   'период',
#   'ссср',
#   '1953',
#   'год',
#   'наш',
#   'эксперт',
#   'антон',
#   'долина',
#   'тамара',
#   'эйдельман',
#   'андрей',
#   'звягинцев',
#   'александр',
#   'роднянский',
#   'всеволод',
#   'коршунов',
#   'алексей',
#   'айга',
#   'зара',
#   'абдуллаев',
#   'елена',
#   'стишов',
#   'станислав',
#   'дединский',
#   'наталья',
#   'рябчиковый',
#   'наталья',
#   'нусиновый',
#   'другой',
#   'рассказывать',
#   'трудность',
#   'киноиндустрия',
#   'время',
#   'война',
#   'малокартинья',
#   'предвестие',
#   'оттепель',
#   'конец',
#   '1940',
#   'х',
#   'начало',
#   '1950',
#   'х',
#   'рф',
#   'объявить',
#   'иностранный',
#   'агент',
#   'эпизод',
#   'узнать',
#   'творчество',
#   'сергей',
#   'эйзенштейн',
#   'григорий',
#   'александров',
#   'григорий',
#   'козинцев',
#   'всеволод',
#   'пудовкин',
#   'борис',
#   'барнет',
#   'иван',
#   'пырьев',
#   'другой',
#   'https',
#   'youtu',
#   'bxuljhcr0uq'],
#  ['кино',
#   'вечер',
#   'смотреть',
#   'первый',
#   'серия',
#   'документальный',
#   'фильм',
#   'история',
#   'российский',
#   'кино',
#   'рождение',
#   'миф',
#   'первый',
#   'эпизод',
#   'сосредоточиться',
#   'развитие',
#   'кинематограф',
#   'дореволюционный',
#   'россия',
#   'рождение',
#   'советский',
#   'кино',
#   'также',
#   'появление',
#   'звук',
#   'кино',
#   'https',
#   'youtu',
#   '5zlulopdctk'],
#  ['завтра',
#   'состояться',
#   'премьера',
#   'первый',
#   'серия',
#   'документальный',
#   'фильм',
#   'история',
#   'российский',
#   'кино',
#   'рождение',
#   'миф',
#   'первый',
#   'эпизод',
#   'рассказывать',
#   'история',
#   'кино',
#   'зарождение',
#   'первый',
#   'звуковой',
#   'фильм',
#   'путёвка',
#   'жизнь',
#   'ожидание',
#   'премьера',
#   'рассматривать',
#   'постер',
#   'самый',
#   'громкий',
#   'фильм',
#   'эпоха'],
#  ['10',
#   'март',
#   'журнал',
#   'искусство',
#   'кино',
#   'провести',
#   'youtube',
#   'премьера',
#   'первый',
#   'эпизод',
#   'документальный',
#   'фильм',
#   'история',
#   'российский',
#   'кино',
#   'рождение',
#   'миф',
#   'это',
#   'двухсерийный',
#   'фильм',
#   'первый',
#   'десятилетие',
#   'отечественный',
#   'кинематограф',
#   'момент',
#   'зарождение',
#   '1953',
#   'год',
#   'смерть',
#   'сталин',
#   'первый',
#   'дыхание',
#   'оттепель',
#   'фильм',
#   'охватывать',
#   'важный',
#   'веха',
#   'развитие',
#   'историк',
#   'кино',
#   'культуролог',
#   'режиссёр',
#   'сценарист',
#   'вписывать',
#   'история',
#   'кинематограф',
#   'широкий',
#   'контекст',
#   'рассматривать',
#   'путь',
#   'который',
#   'пройти',
#   'страна',
#   'царский',
#   'россия',
#   'тоталитарный',
#   'государство',
#   'сталин',
#   'наш',
#   'эксперт',
#   'антон',
#   'долина',
#   'тамара',
#   'эйдельман',
#   'андрей',
#   'звягинцев',
#   'александр',
#   'роднянский',
#   'алексей',
#   'айга',
#   'другой',
#   'пробовать',
#   'проникнуть',
#   'быть',
#   'создать',
#   'экран',
#   'миф',
#   'который',
#   'продолжать',
#   'влиять',
#   'современный',
#   'россия',
#   'рф',
#   'объявить',
#   'иностранный',
#   'агент'],
#  ['проходить',
#   'работа',
#   'сергей',
#   'эйзенштейн',
#   'съёмочный',
#   'группа',
#   'сша',
#   'какой',
#   'политический',
#   'индустриальный',
#   'процесс',
#   'накладываться',
#   'поездка',
#   'публиковать',
#   'текст',
#   'доклад',
#   'наталья',
#   'рябчиковый',
#   'прочитать',
#   'рамка',
#   'научно',
#   'популярный',
#   'конференция',
#   'дондуреевский',
#   'чтение',
#   'https',
#   'bit',
#   'ly',
#   '3xiyccr'],
#  ['публиковать',
#   'текст',
#   'доклад',
#   'евгений',
#   'марголита',
#   'противостояние',
#   'развернуться',
#   'кино',
#   '1920',
#   'х',
#   'год',
#   'киноорганизация',
#   'доклад',
#   'прочитать',
#   'рамка',
#   'конференция',
#   'дондуреевский',
#   'чтение',
#   'https',
#   'bit',
#   'ly',
#   '3gnwdb6'],
#  ['китай',
#   'показываться',
#   'советский',
#   'кино',
#   'почему',
#   'он',
#   'проявляться',
#   'интерес',
#   'какой',
#   'отношение',
#   'складываться',
#   'советский',
#   'китайский',
#   'кинематографист',
#   'накладываться',
#   'общественно',
#   'политический',
#   'контекст',
#   'доклад',
#   'сергей',
#   'каптерёв',
#   'https',
#   'bit',
#   'ly',
#   '3znbygi'],
#  ['рамка',
#   'выставка',
#   'шестидесятый',
#   'слово',
#   'образ',
#   'центр',
#   'вознесенский',
#   'пройти',
#   'цикл',
#   'лекция',
#   'посвятить',
#   'кинематографист',
#   '60',
#   'х',
#   'судьба',
#   'журнал',
#   'искусство',
#   'кино',
#   'период',
#   'посмотреть',
#   'наш',
#   'youtube',
#   'канал',
#   'https',
#   'bit',
#   'ly',
#   '3qsbdrr'],
#  ['эйзенштейновский',
#   'семинар',
#   'цикл',
#   'лекция',
#   'теория',
#   'кино',
#   'режиссура',
#   'посвятить',
#   'сергей',
#   'эйзенштейн',
#   'пригласить',
#   'спикер',
#   'рассказывать',
#   'художественный',
#   'решение',
#   'документальный',
#   'кино',
#   'экспериментальный',
#   'мастерская',
#   'эйзенштейн',
#   'https',
#   'bit',
#   'ly',
#   '3jzruyq'],
#  ['приглашать',
#   'посмотреть',
#   'видеозапись',
#   'доклад',
#   'сделать',
#   'киновед',
#   'исследователь',
#   'кино',
#   'рамка',
#   'дондуреевский',
#   'чтение',
#   'первый',
#   'научно',
#   'популярный',
#   'конференция',
#   'посвятить',
#   'кинопроцесс',
#   '20',
#   'х',
#   'год',
#   'https',
#   'bit',
#   'ly',
#   '3xbas9v'],
#  ['приглашать',
#   'посетить',
#   'специальный',
#   'показ',
#   'фильм',
#   'страсть',
#   'андрей',
#   'расширить',
#   'версия',
#   'андрей',
#   'рублёв',
#   'андрей',
#   'тарковский',
#   '▫️4',
#   'январь',
#   '20',
#   '15',
#   'москва',
#   'кинотеатр',
#   'домжур',
#   'https',
#   'bit',
#   'ly',
#   '3gicxfl',
#   '▫️6',
#   'январь',
#   '16',
#   '00',
#   'санкт',
#   'петербург',
#   'киностудия',
#   'лендок',
#   'https',
#   'bit',
#   'ly',
#   '3x04gxz',
#   '▫️6',
#   'январь',
#   '20',
#   '30',
#   'санкт',
#   'петербург',
#   'кинотеатр',
#   'аврора',
#   'https',
#   'bit',
#   'ly',
#   '3joeh7m'],
#  ['дорогой',
#   'друг',
#   'последний',
#   'день',
#   '2022',
#   'год',
#   'писать',
#   'редакция',
#   'итог',
#   'год',
#   'план',
#   'будущее',
#   'номер',
#   '1',
#   '2',
#   '2023',
#   'год',
#   'временно',
#   'временно',
#   'стать',
#   'последний',
#   'печатный',
#   'выпуск',
#   'журнал',
#   'это',
#   'значит',
#   'прекращать',
#   'работа',
#   'искусство',
#   'кино',
#   'продолжить',
#   'существовать',
#   'онлайн',
#   'режим',
#   'множество',
#   'идея',
#   'который',
#   'начать',
#   'воплощать',
#   'жизнь',
#   'новый',
#   'год',
#   'наступать',
#   'новый',
#   'год',
#   'спасибо',
#   'мы',
#   'непростой',
#   'время',
#   'верить',
#   'перемена',
#   'точно',
#   'настать',
#   'прочитать',
#   'письмо',
#   'редакция',
#   'целиком',
#   'https',
#   'bit',
#   'ly',
#   '3gpzahm'],
#  ['читаемый',
#   'текст',
#   'доклад',
#   'юлия',
#   'козицкий',
#   'творчество',
#   'дзиг',
#   'вертов',
#   'осмысляться',
#   'тема',
#   'восток',
#   'культура',
#   'образ',
#   'доклад',
#   'стать',
#   'часть',
#   'дондуреевский',
#   'чтение',
#   'научно',
#   'популярный',
#   'конференция',
#   'кино',
#   '1920',
#   'х',
#   'год',
#   'https',
#   'bit',
#   'ly',
#   '3i4zqjl'],
#  ['доклад',
#   'прочитать',
#   'рамка',
#   'дондуреевский',
#   'чтение',
#   'алиса',
#   'соломонов',
#   'рассказывать',
#   'советский',
#   'зритель',
#   'критика',
#   'воспринимать',
#   'фильм',
#   'пауль',
#   'вегенера',
#   'кинорепутация',
#   'немецкий',
#   'режиссёр',
#   'https',
#   'bit',
#   'ly',
#   '3wtrlje'],
#  ['blickk',
#   'это',
#   'новый',
#   'медиа',
#   'кино',
#   'рассказывать',
#   'киноискусство',
#   'индустрия',
#   'увлекательно',
#   'интерактивно',
#   'помощь',
#   'тест',
#   'подкаст',
#   'интервью',
#   'перевод',
#   'репортаж',
#   'наш',
#   'цель',
#   'вдохновлять',
#   'молодой',
#   'автор',
#   'делать',
#   'кино',
#   'доступный',
#   'интересный',
#   'любим',
#   'снобизм',
#   'рада',
#   'здоровый',
#   'дискуссия',
#   '•',
#   'blickk',
#   'movie',
#   'советовать',
#   'фильм',
#   '•',
#   'blickk',
#   'top',
#   'список',
#   'кинолента',
#   '•',
#   'blickk',
#   'bts',
#   'кадр',
#   '•',
#   'blickk',
#   'ost',
#   'избранный',
#   'саундтрек',
#   '•',
#   'blickk',
#   'retro',
#   'забытый',
#   'классика',
#   '•',
#   'blickk',
#   'community',
#   'контент',
#   'наш',
#   'подписчик',
#   '•',
#   'blickk',
#   'details',
#   'деталь',
#   'который',
#   'мочь',
#   'пропустить',
#   '•',
#   'blickk',
#   'подборка',
#   'случайный',
#   'подборка',
#   '18'],
#  ['японский', 'постер', 'фильм', 'фарго', 'fargo', '1996'],
#  ['💔',
#   'время',
#   'добровольно',
#   'отреставрировать',
#   'надгробный',
#   'плита',
#   'бастер',
#   'китон'],
#  ['зарисовка',
#   'режиссёр',
#   'ари',
#   'астер',
#   'фильм',
#   'солнцестояние',
#   'midsommar',
#   '2019'],
#  ['адам',
#   'драйвер',
#   'эндрю',
#   'гарфилд',
#   'объектив',
#   'джейк',
#   'чессума',
#   'jake',
#   'chessum'],
#  ['молодой', 'кристоф', 'вальц'],
#  ['2021', 'сон', 'кан', 'хо', 'dazed'],
#  ['✨', 'хаяо', 'миядзак', '81'],
#  ['альтернативный',
#   'постер',
#   'фильм',
#   'йоргос',
#   'лантимос',
#   'убийство',
#   'священный',
#   'олень',
#   'killing',
#   'sacred',
#   'deer',
#   '2017'],
#  ['🍇',
#   'адам',
#   'сэндлера',
#   'кадр',
#   'неогранённый',
#   'драгоценность',
#   'uncut',
#   'gems',
#   '2019'],
#  ['аня',
#   'тейлор',
#   'джа',
#   'александр',
#   'скасгарда',
#   'съёмка',
#   'фильм',
#   'варяг',
#   'northman',
#   '2022'],
#  ['обложка',
#   'журнал',
#   'фильм',
#   'французский',
#   'вестник',
#   'french',
#   'dispatch',
#   '2021'],
#  ['постер',
#   'фильм',
#   'майк',
#   'миллс',
#   'камон',
#   'камон',
#   'c',
#   'mon',
#   'c’mon',
#   '2021',
#   'фильм',
#   'выйти',
#   'российский',
#   'прокат',
#   '17',
#   'февраль',
#   '2022',
#   'ждать'],
#  ['вонг', 'кара', 'вай'],
#  ['психо',
#   'psycho',
#   '1960',
#   'малхолланд',
#   'драйв',
#   'mulholland',
#   'drive',
#   '2001',
#   'апокалипсис',
#   'сегодня',
#   'apocalypse',
#   '1979',
#   'фаворитка',
#   'favourite',
#   '2018',
#   'credit',
#   'cinematologist',
#   'instagrаm'],
#  ['хаяо', 'миядзак', 'порко', 'россо'],
#  ['эпатажный',
#   'домашний',
#   'агрессивно',
#   'заботливый',
#   'комьюнити',
#   'онлайн',
#   'академия',
#   'изучение',
#   'немецкий',
#   'язык',
#   'интенсивный',
#   'ежедневный',
#   'курс',
#   'уровень',
#   'а0',
#   'с2',
#   'также',
#   'адский',
#   'интенсив',
#   'подготовка',
#   'гёте',
#   'в2',
#   'классический',
#   'курс',
#   'занятие',
#   '3',
#   'день',
#   'неделя',
#   'разговорный',
#   'читальный',
# ...
#   'react',
#   '✓',
#   'адаптивный',
#   'вёрстка',
#   'сайт',
#   'html',
#   'css',
#   '✓',
#   'проект',
#   'javascript',
#   'приложение',
#   'список',
#   'задача',
#   'todo',
#   '✓',
#   'слайдер',
#   'javascript',
#   'урок',
#   'практика',
#   'новичок',
#   '✓',
#   'html',
#   'css',
#   'адаптивный',
#   'вёрстка',
#   'сайт',
#   'freelance',
#   'portfolio',
#   'тёмный',
#   'тема',
#   'js',
#   'css',
#   'переменный',
#   '✓',
#   'сайт',
#   'портфолио',
#   'react',
#   'js',
#   'урок',
#   'новичок',
#   'базовый',
#   'вводный',
#   'курс',
#   'react',
#   'начинающий',
#   '✓',
#   'адаптивный',
#   'вёрстка',
#   'сайт',
#   'scss',
#   'js',
#   'объяснять',
#   'шаг',
#   'css',
#   'grid',
#   'бэм',
#   'макет',
#   'lofthouse',
#   'video',
#   'practice',
#   'frontend'],
#  ['php',
#   'academy',
#   'обучать',
#   'телеграм',
#   'канал',
#   'программист',
#   'это',
#   'достаточно',
#   'простой',
#   'язык',
#   'изучение',
#   'особенно',
#   'начинающий',
#   'разработчик',
#   'php',
#   'самый',
#   'популярный',
#   'язык',
#   'веб',
#   'применяться',
#   '40',
#   'сайт',
#   'мир',
#   'хотеть',
#   'вывести',
#   'свой',
#   'навык',
#   'веб',
#   'разработка',
#   'новый',
#   'уровень',
#   'практика',
#   'тратить',
#   'время',
#   'бесполезный',
#   'гайда',
#   'рекомендовать',
#   'подписаться',
#   'php',
#   'академия',
#   'подписаться',
#   'https',
#   'vk',
#   'cc',
#   'cp4qeh'],
#  ['ждать',
#   'будущее',
#   '–',
#   'создать',
#   'участвовать',
#   'конкурс',
#   'карелия',
#   'взгляд',
#   'будущее',
#   'представить',
#   'свой',
#   'образ',
#   'республика',
#   'завтрашний',
#   'день',
#   'воображать',
#   'карелия',
#   '50',
#   '100',
#   '1000',
#   'год',
#   'возможность',
#   'воплотить',
#   'фантазия',
#   'изображение',
#   'присоединяться',
#   'конкурс',
#   'показать',
#   'свой',
#   'видение',
#   'будущее',
#   'команда',
#   'проект',
#   'карелия',
#   'против',
#   'ия',
#   'приглашать',
#   'профессиональный',
#   'художник',
#   'дизайнер',
#   'любитель',
#   'творчество',
#   'попробовать',
#   'сила',
#   'генеративный',
#   'искусство',
#   'сформулировать',
#   'свой',
#   'представление',
#   'вид',
#   'текст',
#   'выбрать',
#   'нейросеть',
#   'который',
#   'подходить',
#   'ваш',
#   'задача',
#   'задать',
#   'нужный',
#   'настройка',
#   'стиль',
#   'изображение',
#   'уточнять',
#   'запрос',
#   'настройка',
#   'пока',
#   'получиться',
#   'нужный',
#   'результат',
#   'отправить',
#   'готовый',
#   'нейроарт',
#   'форма',
#   'сайт',
#   'https',
#   'startup',
#   'karelia',
#   'ru',
#   'kareliya',
#   'protiv',
#   'ii',
#   'vystavk',
#   'приём',
#   'заявка',
#   'идти',
#   '30',
#   'июнь',
#   'включительно',
#   'остаться',
#   '3',
#   'день',
#   'жюри',
#   'выбрать',
#   '30',
#   'работа',
#   'быть',
#   'опубликовать',
#   'социальный',
#   'сеть',
#   'проект',
#   'карелия',
#   'против',
#   'ия',
#   'представить',
#   'выставка',
#   'автор',
#   'хороший',
#   'нейроарт',
#   'получить',
#   'приз',
#   'сертификат',
#   'также',
#   'возможность',
#   'принять',
#   'участие',
#   'ted',
#   'конференция',
#   'ия',
#   '8',
#   'июль',
#   'конец',
#   'проект',
#   'пройти',
#   'аукцион',
#   'собранный',
#   'средство',
#   'продажа',
#   'произведение',
#   'быть',
#   'направить',
#   'поддержка',
#   'цифровой',
#   'грамотность',
#   'школа',
#   'карелия',
#   'пусть',
#   'ваш',
#   'творческий',
#   'идея',
#   'стать',
#   'вдохновение',
#   'помочь',
#   'ребёнок',
#   'создавать',
#   'хороший',
#   'будущее',
#   'открыть',
#   'возможность',
#   'искусственный',
#   'интеллект',
#   '🚀',
#   '✅',
#   'вступать',
#   'группа',
#   'проект',
#   'https',
#   'vk',
#   'com',
#   'kareliavsai',
#   '✅',
#   'подписываться',
#   'телеграм',
#   'канал',
#   'https',
#   'kareliavsai',
#   '✔',
#   'присоединяться',
#   'масштабный',
#   'движение',
#   'который',
#   'менять',
#   'мир'],
#  ['book', 'math', 'interesting'],
#  ['математик',
#   'объяснение',
#   'ᐅ',
#   'операция',
#   'система',
#   'счисление',
#   'один',
#   'видео',
#   'ᐅ',
#   'равновесие',
#   'неш',
#   'объяснение',
#   'математический',
#   'смысл',
#   'ᐅ',
#   'деление',
#   'ноль',
#   'объяснение',
#   'математический',
#   'смысл',
#   'ᐅ',
#   'число',
#   'фибоначча',
#   '1',
#   '618',
#   'объяснение',
#   'математический',
#   'смысл',
#   'золотой',
#   'сечение',
#   'ᐅ',
#   'нужный',
#   'вектор',
#   'объяснение',
#   'математический',
#   'смысл',
#   'ᐅ',
#   'нужный',
#   'система',
#   'счисление',
#   'объяснение',
#   'смысл',
#   'ᐅ',
#   'нужный',
#   'интеграл',
#   'объяснение',
#   'математический',
#   'смысл',
#   'ᐅ',
#   'число',
#   'e',
#   '2',
#   '718',
#   'объяснение',
#   'математический',
#   'смысл',
#   'ᐅ',
#   'сумма',
#   'число',
#   'равный',
#   '1',
#   '12',
#   'объяснение',
#   'математически',
#   'что',
#   'равный',
#   'бесконечность',
#   'ᐅ',
#   'число',
#   'пи',
#   'объяснение',
#   'математический',
#   'смысл',
#   'video',
#   'math',
#   'interesting'],
#  ['book', 'python', 'task'],
#  ['произойти',
#   'изменение',
#   'ctos',
#   'являться',
#   'главный',
#   'система',
#   'объединять',
#   'человек'],
#  ['академический',
#   'программирование',
#   'сообщество',
#   'студент',
#   'профессионал',
#   'увлечь',
#   'программирование',
#   'интересный',
#   'новость',
#   'мир',
#   'амбассадор',
#   'компания',
#   'vk',
#   'ведущий',
#   'группа',
#   'регулярно',
#   'проводить',
#   'мероприятие',
#   'такой',
#   'вебинар',
#   'курс',
#   'мастер',
#   'класс',
#   'помочь',
#   'участник',
#   'группа',
#   'улучшить',
#   'свой',
#   'навык',
#   'узнать',
#   'новый',
#   'присоединяться',
#   'наш',
#   'группа'],
#  ['профессиональный',
#   'фотография',
#   'ия',
#   'нейросеть',
#   'запросить',
#   '15',
#   'фотография',
#   'селфи',
#   'проанализировать',
#   'лицо',
#   'дать',
#   'выбор',
#   'ваш',
#   'фото',
#   'шаблон',
#   'попробовать',
#   'retrato',
#   'ссылочка',
#   'https',
#   'www',
#   'retrato',
#   'app'],
#  ['быстро',
#   'составить',
#   'представление',
#   'содержание',
#   'обширный',
#   'материал',
#   'необязательно',
#   'читать',
#   'полностью',
#   '–',
#   'yandexgpt',
#   'yalm',
#   '2',
#   '0',
#   'пересказать',
#   'статья',
#   'вид',
#   'краткий',
#   'тезис',
#   'пользователь',
#   'поделиться',
#   'ссылка',
#   'изложение',
#   'мессенджер',
#   'технология',
#   'работать',
#   'режим',
#   'бета',
#   'тестирование',
#   'сервис',
#   '300',
#   'ya',
#   'ru'],
#  ['нейронка',
#   'тиктокер',
#   'блогер',
#   'убирать',
#   'шум',
#   'видео',
#   'ия',
#   'adobe',
#   'enhance',
#   'ничуть',
#   'плохой',
#   'тот',
#   'бесплатно',
#   'русский',
#   'язык',
#   'ссылочка',
#   'https',
#   'auphonic',
#   'com'],
#  ['поменять',
#   'причёска',
#   'hairstyleai',
#   'это',
#   'нейронка',
#   'который',
#   'использовать',
#   'ия',
#   'создание',
#   'причёска',
#   'фотография',
#   'просто',
#   'загружать',
#   'свой',
#   'фото',
#   'выбирать',
#   'один',
#   'предложить',
#   'затем',
#   'применять',
#   'стиль',
#   'цвет',
#   'длина',
#   'волос',
#   'готовый'],
#  ['нейросеть',
#   'показать',
#   'меняться',
#   'легендарный',
#   'автомобиль',
#   'течение',
#   'сотня',
#   'год',
#   'модель',
#   'душа'],
#  ['очень',
#   'красивый',
#   'генерация',
#   'midjourney',
#   'банк',
#   'coca',
#   'cola',
#   'стилистика',
#   'разный',
#   'страна',
#   'добрый',
#   'ловить',
#   'идея',
#   'дизайн'],
#  ['видео',
#   'симуляция',
#   'гибель',
#   'титан',
#   'неделя',
#   'обсуждать',
#   'батискаф',
#   'который',
#   '5',
#   'человек',
#   'отправиться',
#   'смотреть',
#   'обломок',
#   'титаник',
#   'начало',
#   'неделя',
#   'связь',
#   'они',
#   'пропасть',
#   'вчера',
#   'вечером',
#   'стать',
#   'известно',
#   'весь',
#   'экипаж',
#   'погибнуть',
#   'причина',
#   'вероятно',
#   'стать',
#   'имплозия',
#   'взрыв',
#   'направить',
#   'внутрь',
#   'такой',
#   'явление',
#   'возникать',
#   'сильный',
#   'давление',
#   'батискаф',
#   'титан',
#   'мгновенно',
#   'сжать',
#   'это',
#   'произойти',
#   '487',
#   'метр',
#   'место',
#   'крушение',
#   'печально',
#   'известный',
#   'лайнер'],
#  ['пользователь',
#   'реддит',
#   'рассказать',
#   'использовать',
#   'chatgpt',
#   'прочитать',
#   'запомнить',
#   'любой',
#   'книга',
#   'считать',
#   'минута',
#   'идеальный',
#   'схема',
#   'нужно',
#   'прокачать',
#   'какой',
#   'навык',
#   'работа',
#   'подготовиться',
#   'экзамен',
#   'ловить',
#   'промт',
#   '№1',
#   'составить',
#   'краткий',
#   'пересказ',
#   'название',
#   'книга',
#   'имя',
#   'автор',
#   'промт',
#   '№2',
#   'составить',
#   'список',
#   'глава',
#   'книга',
#   'список',
#   'стоить',
#   'выбрать',
#   'самый',
#   'нужный',
#   'полезный',
#   'глава',
#   'промт',
#   '№3',
#   'название',
#   'нужный',
#   'глава',
#   'какой',
#   '20',
#   'информация',
#   'вставить',
#   'задача',
#   'обучение',
#   'являться',
#   'наиболее',
#   'важный',
#   'помочь',
#   'понять',
#   '80',
#   'тема',
#   'промт',
#   'быть',
#   'самый',
#   'важный',
#   'момент',
#   'глава',
#   'лишний',
#   'чепуха',
#   'остаться',
#   'запомнить',
#   'всё',
#   'это',
#   'промт',
#   '№4',
#   'превратить',
#   'ключевой',
#   'урок',
#   'глава',
#   'увлекательный',
#   'история',
#   'метафора',
#   'облегчить',
#   'запоминание',
#   'вуаля',
#   'запомнить',
#   'нужный',
#   'материал',
#   'сэкономить',
#   'куча',
#   'час',
#   'который',
#   'потратить',
#   'прочтение',
#   'весь',
#   'книга'],
#  ['🎮',
#   'нейронка',
#   'создание',
#   'игра',
#   'игровой',
#   'студия',
#   'frvr',
#   'выпустить',
#   'frvr',
#   'forge',
#   'нейросеть',
#   'который',
#   'создавать',
#   'игра',
#   'текстовый',
#   'описание',
#   'ранний',
#   'генерировать',
#   'фотка',
#   'гифка',
#   'видео',
#   'ия',
#   'добраться',
#   'игровой',
#   'индустрия',
#   'создавать',
#   'свой',
#   'игра',
#   'смочь',
#   'каждый',
#   'главное',
#   'знать',
#   'правильно',
#   'написать',
#   'промт',
#   'пока',
#   'записаться',
#   'бесплатный',
#   'бета',
#   'тест',
#   'https',
#   'clck',
#   'ru',
#   '34m79b'],
#  ['поисковик',
#   'com',
#   'будущее',
#   'google',
#   'база',
#   'нейросеть',
#   'com',
#   'задавать',
#   'новый',
#   'планка',
#   'общение',
#   'пользователь',
#   'нейросеть',
#   'поиск',
#   'информация',
#   'далеко',
#   'идеально',
#   'первый',
#   'место',
#   'выводить',
#   'удобство',
#   'сёрфинг',
#   'интернет',
#   'вместе',
#   'интеграция',
#   'нейросеть',
#   'выглядеть',
#   'очень',
#   'круто',
#   'многообещающий',
#   'основный',
#   'новшество',
#   '•',
#   'новый',
#   'алгоритм',
#   '•',
#   'табличный',
#   'дизайн',
#   '•',
#   'сортировка',
#   'результат',
#   '•',
#   'отсутствие',
#   'реклама',
#   '•',
#   'интегрировать',
#   'нейросеть'],
#  ['👀',
#   'яндекс',
#   'маркет',
#   'появиться',
#   'возможность',
#   'создавать',
#   'описание',
#   'товар',
#   'помощь',
#   'yandexgpt',
#   'yandexgpt',
#   'писать',
#   'текст',
#   'данные',
#   'карточка',
#   'товар',
#   'поэтому',
#   'информация',
#   'карточка',
#   'подробный',
#   'точнее',
#   'нейросеть',
#   'рассказать',
#   'товар',
#   'текст',
#   'создать',
#   'yalm',
#   '2',
#   '0',
#   'редактировать',
#   'нейросеть',
#   'создать',
#   'несколько',
#   'вариант',
#   'описание',
#   'товар',
#   'повторно',
#   'нажать',
#   'кнопка',
#   'новый',
#   'технология',
#   'доступный',
#   'весь',
#   'магазин',
#   'сервис',
#   'это',
#   'сравниться',
#   'перевод',
#   'описание',
#   'товар',
#   'aliexpress'],
#  ['midjourney',
#   'навести',
#   'суета',
#   'химия',
#   '⛔изучать',
#   'химия',
#   'обычно',
#   '🕋',
#   '✅изучать',
#   'химия',
#   'помощь',
#   'midjorney',
#   '👁',
#   'generated'],
#  ['google',
#   'фото',
#   'научиться',
#   'узнавать',
#   'человек',
#   'фотография',
#   'стоять',
#   'спина',
#   'камера',
#   'функция',
#   'работать',
#   'фото',
#   'который',
#   'сделать',
#   'несколько',
#   'год',
#   'назад'],
#  ['apple',
#   'требовать',
#   'ассоциация',
#   'фермер',
#   'отказаться',
#   'логотип',
#   'яблоко',
#   'apple',
#   'хотеть',
#   'получить',
#   'право',
#   'изображение',
#   'яблоко',
#   'компания',
#   'столкнуться',
#   'ассоциация',
#   'фермер',
#   'швейцария',
#   'чей',
#   'логотип',
#   '111',
#   'год',
#   'яблоко',
#   'швейцарский',
#   'суд',
#   'вряд',
#   'принять',
#   'решение',
#   'близкий',
#   'месяц',
#   'год',
#   'однако',
#   'фермер',
#   'прийтись',
#   'проводить',
#   'ребрендинг',
#   'это',
#   'стоить',
#   'миллион'],
#  ['держать',
#   'классный',
#   'сайт',
#   'нейронками',
#   'портал',
#   'ai',
#   'tool',
#   'tracker',
#   'разместить',
#   'куча',
#   'ия',
#   'инструмент',
#   'который',
#   'удобно',
#   'разделить',
#   'полочка',
#   'найтись',
#   'дизайн',
#   'учёба',
#   'копирайтинг',
#   'так',
#   'далее',
#   'ссылочка',
#   'https',
#   'aitooltracker',
#   'com',
#   'ai',
#   'categories'],
#  ['удачный', 'день', '😉'],
#  ['привет',
#   'это',
#   'читать',
#   'желать',
#   'ты',
#   'позитивный',
#   'настроение',
#   'поздравлять',
#   'найти',
#   'наш',
#   'сообщество',
#   'который',
#   'рада',
#   'видеть',
#   'подписываться',
#   'располагаться'],
#  ['новый',
#   'сервис',
#   'готовый',
#   'заплатить',
#   'ваш',
#   'мнение',
#   'это',
#   'шутка',
#   'vk',
#   'cc',
#   'cowocd',
#   'наградить',
#   'пройти',
#   'анкета',
#   'опрос',
#   'это',
#   'работать',
#   'средство',
#   'вывести',
#   'телефон',
#   '1000',
#   'гарантировать',
#   '100',
#   'прозрачность',
#   'никакой',
#   'карта',
#   'привязывать',
#   'нужно'],
#  ['девушка', 'заставлять', 'смотреть', 'фильм', 'который', 'ты', 'нравиться'],
#  ['проверить',
#   'свой',
#   'уровень',
#   'аналитик',
#   'общение',
#   'сыграть',
#   'бесплатный',
#   'игра',
#   'https',
#   'vk',
#   'cc',
#   'coto2a',
#   'игра',
#   'симуляция',
#   'business',
#   'cats',
#   '–',
#   'разработка',
#   'образовательный',
#   'центр',
#   'алабуг',
#   'политех',
#   'пройти',
#   'любой',
#   'желать',
#   'игра',
#   'нужно',
#   'выращивать',
#   'продавать',
#   'онлайн',
#   'кот',
#   'прокачивать',
#   'самый',
#   'свой',
#   'навык',
#   'аналитический',
#   'мышление',
#   'общительность',
#   'смочь',
#   'дойти',
#   'уровень',
#   '1',
#   'пригласить',
#   'очный',
#   'этап',
#   'смочь',
#   'поступить',
#   'егэ',
#   'огэ',
#   'прочий',
#   'неприятный',
#   'экзамен',
#   'переходить',
#   'регистрироваться',
#   'проверять',
#   'свой',
#   'способность',
#   'это',
#   'лето',
#   'https',
#   'vk',
#   'cc',
#   'coto2a'],
#  ['тот', 'шарить', 'мем'],
#  ['делать', 'переработать', 'вещь'],
#  ['приготовление', 'бекон', 'самый', 'необычный', 'образ'],
#  ['человек', 'сильно', 'испугаться', 'пранка'],
#  ['собака', 'ходить', 'рынок'],
#  ['именно', 'ранний', 'создаваться', 'спецэффект'],
#  ['заслуживать', 'премия', 'муж', 'год'],
#  ['кошка', 'находить', 'общий', 'язык', 'ребёнок'],
#  ['самый', 'свидание', 'отличник'],
#  ['парень', 'видимо', 'бояться', 'высота'],
#  ['немного', 'милот', 'лента'],
#  ['целый', 'стая', 'обезьянка', 'решить', 'убежать'],
#  ['наш', 'время', 'создать', 'торт', 'любой', 'форма'],
#  ['кошка', 'расти', 'среди', 'собака'],
#  ['оказываться', 'ведьма', 'очень', 'неплохо', 'жить'],
#  ['ёуёуё',
#   'цель',
#   '2000',
#   'человек',
#   'опенинга',
#   'мем',
#   'эдита',
#   'обзор',
#   'пикчи',
#   'ваш',
#   'активность',
#   'контент'],
#  ['неожиданный', 'закрепа', 'господин', 'завтра', 'мем', '👾'],
#  ['такой', 'лицо', 'садиться', 'опенинга', '🤓', 'следить', 'новость'],
#  ['видимо', 'получить', 'хотеть', '😨'],
#  ['постепенно', 'возвращаться', 'свой', 'место', '👺'],
#  ['около', 'гениальный', '👀'],
#  ['решить',
#   'продолжить',
#   'прошлый',
#   'мем',
#   '🚜',
#   'скоро',
#   'быть',
#   'разработка',
#   'опенинга'],
#  ['сделать', 'новый', 'эдита', '🧟\u200d♂', 'поздравлять', '2000', 'друг'],
#  ['обложка',
#   'последний',
#   'выходить',
#   'опенинга',
#   'весьма',
#   'актуально',
#   'кстати',
#   '🦎плюс',
#   'небольшой',
#   'новость',
#   'делать',
#   'новый',
#   'эдита',
#   'скорый',
#   'время',
#   'голосовалка',
#   'хороший',
#   'эдита',
#   'среди',
#   'старый',
#   'новый'],
#  ['какой', 'город', 'жить', '♻'],
#  ['немного', 'вайба', 'ночной', 'токио', 'музыкальный', 'пауза', '💆\u200d♂'],
#  ['зевать', 'утро', '😨'],
#  ['хота', 'лайна', 'мая', '3', 'выйти', '🐔'],
#  ['хороший', 'песня', 'поднятие', 'настроение', 'любой', 'время', '💀'],
#  ['эпичный',
#   'вечер',
#   '👹',
#   'завтра',
#   'быть',
#   'мем',
#   'ждать',
#   'кстати',
#   'юбилейный',
#   'мем'],
#  ['утренний', 'мем', 'весьма', 'тематичный', '😵'],
#  ['группа', 'нести', 'развлекательный', 'характер®'],
#  ['здравый', 'движ', 'залетать', 'брат', 'сёстры🔥👋🏻'],
#  ['уважаемый',
#   'бачайчан',
#   'замечательный',
#   'беседа',
#   'общаться',
#   'человек',
#   'ждать',
#   '❤️🔥',
#   'https',
#   'vk',
#   'join',
#   'ajq1d7ybiydupqmdpb91a1dh'],
#  ['вроде',
#   'никто',
#   'сказать',
#   'сказать',
#   'поздравлять',
#   '2',
#   '4к',
#   'подписчик',
#   '😅',
#   'удача',
#   'развитие',
#   '👍',
#   'онон'],
#  ['ух',
#   'добрый',
#   'утро',
#   'весь',
#   'проснуться',
#   'бабах',
#   'думать',
#   'это',
#   'запад',
#   'это',
#   'дождь',
#   'улица',
#   'идти',
#   '🥶😅'],
#  ['уважаемый',
#   'бачайчан',
#   'замечательный',
#   'беседа',
#   'общаться',
#   'человек',
#   'ждать',
#   '❤️🔥',
#   'https',
#   'vk',
#   'join',
#   'ajq1d7ybiydupqmdpb91a1dh'],
#  ['девочка', 'ростов', 'это', 'правда'],
#  ['пригожина', 'уходить', 'ахуенный', 'байт'],
#  ['ребята', 'сидеть', 'дом', 'нахуй👋🏻'],
#  ['наебали',
#   'пацан',
#   'резня',
#   'среди',
#   'народ',
#   'владелец',
#   'сейчас',
#   'ехать',
#   'ахматовца',
#   'ростов'],
#  ['обстановка',
#   'южный',
#   'военный',
#   'штаб',
#   'г',
#   'ростов',
#   'дон',
#   '05',
#   '06',
#   'мск',
#   'стрельба',
#   'пжлст',
#   '❤️']]

# %% [markdown]
# Обучим w2v модель на наших текстах.

# %%
w2v_model = Word2Vec(
    all_texts,
    min_count=10,
    window=2,
    vector_size=300,
    negative=10,
    alpha=0.03,
    min_alpha=0.0007,
    sample=6e-5,
    sg=1)

w2v_model.train(all_texts, total_examples=w2v_model.corpus_count, epochs=100, report_delay=1)
# Out:
# (292783, 3088900)

# %% [markdown]
# Запишем вспомогательные функции для обработки текстов. Первая вычисляет сходство текста с какой-либо тематикой. Вторая функция вычисляет сходство текста со всеми тематиками и формирует вектор для текста.

# %%
def get_text_similarity(tokenized_text, theme_word):
    text_similarity = 0.
    used_words = 0
    for word in tokenized_text:
        if word in w2v_model.wv.key_to_index:
            text_similarity += w2v_model.wv.similarity(word, theme_word)
            used_words += 1
    if used_words != 0:
        return text_similarity / used_words
    return 0.

def get_themes_characteristics(tokenized_text):
    return [
        get_text_similarity(tokenized_text, 'кино'),
        get_text_similarity(tokenized_text, 'немецкий'),
        get_text_similarity(tokenized_text, 'программирование'),
        get_text_similarity(tokenized_text, 'мем')
    ]

print("Vocabulary size:", len(w2v_model.wv.key_to_index))
print("Vocabulary words:", list(w2v_model.wv.key_to_index.keys()))
# Out:
# Vocabulary size: 584
# Vocabulary words: ['https', 'vk', 'который', 'немецкий', 'com', 'это', 'свой', 'язык', 'фильм', 'год', 'наш', 'работа', 'ru', '–', 'работать', 'новый', 'время', 'habr', 'первый', '2', 'месяц', 'хороший', 'весь', 'день', '1', 'группа', 'каждый', 'самый', 'германия', 'книга', 'cc', 'обучение', 'один', '00', 'deutsch', 'режиссёр', 'команда', 'python', 'хотеть', '3', 'курс', 'узнать', 'любой', 'кино', 'проект', 'человек', 'pylounge', 'игра', 'ваш', '2023', '30', 'возможность', 'быть', 'нужно', 'также', 'разработчик', 'другой', 'мочь', 'делать', 'всё', '5', 'ждать', 'разработка', 'экзамен', 'вопрос', 'уровень', 'просто', 'статья', 'сделать', 'жизнь', 'смочь', 'стать', 'тема', '•', 'очень', 'ссылка', 'знать', 'получить', 'рассказать', 'история', 'u', 'такой', 'бесплатный', 'какой', 'слово', '4', 'документ', 'глагол', '20', 'найти', 'место', 'урок', 'онлайн', 'материал', '7', 'смотреть', 'студент', 'июнь', '10', 'профессия', 'utm', 'добавить', 'ещё', 'помочь', 'мир', 'тот', 'канал', 'кай', 'tproger', 'c', 'поэтому', 'читать', 'программа', '6', '👉', 'билет', 'помощь', 'веб', 'пример', 'занятие', 'сам', 'программирование', 'друг', 'опыт', 'компания', 'писать', 'неделя', 'задача', '2022', 'простой', 'frontend', 'ученик', 'минута', 'страна', 'видео', 'российский', 'россия', 'использовать', 'javascript', 'telegram', 'мем', 'js', 'подготовка', 'сегодня', '🇩🇪', 'интересный', 'текст', 'например', '000', 'жанр', 'данные', 'чат', 'нужный', 'участник', 'outcinema', 'готовый', '50', 'показать', 'пара', 'школа', 'подробный', 'пройти', 'бесплатно', 'специалист', 'а1', 'виза', 'начать', 'именно', 'сайт', 'ребёнок', 'начало', 'комментарий', 'приходить', 'создавать', 'рассказывать', 'её', 'деньга', 'выбрать', 'p', 'главный', 'itcookies', 'роль', 'успешный', '16', 'русский', 'ответ', 'конец', 'боевик', 'список', 'дело', 'график', 'личный', '18', 'вместе', 'несколько', 'учить', 'являться', 'цель', 'говорить', 'дать', 'число', 'imdb', 'автор', 'написать', 'полезный', 'должный', 'драма', 'ты', 'в2', 'х', 'преподаватель', 'новость', 'подписчик', 'лето', 'перевод', 'портрет', 'создать', 'реклама', 'пока', 'book', 'попробовать', '🔥', 'разный', 'сдача', 'проблема', 'бот', 'правило', 'сериал', 'лексика', 'будущее', 'нейросеть', 'дом', 'кто', 'посмотреть', 'июль', 'этот', 'настоящий', 'новинка', 'база', 'сообщество', 'апостиль', 'большой', 'важный', 'учиться', 'версия', 'навык', 'нa', 'поздравлять', 'нуль', 'подписываться', 'рейтинг', 'start', 'пост', 'youtube', 'тестирование', 'мой', 'сказать', 'образ', 'знание', 'путь', 'решить', 'беседа', 'www', 'изучение', 'больший', 'оставлять', 'почему', 'доклад', '→', 'программист', '👍', 'вид', 'комедия', 'топ', 'мы', 'образовательный', '📍как', 'герой', 'полезно', '01', 'в1', 'музыка', 'решение', 'ребята', 'подборка', 'сша', 'ставить', 'приложение', 'семья', 'однако', 'задание', '19', 'заниматься', 'делиться', '₽', 'понять', 'сразу', 'р', 'лицо', 'развитие', 'документальный', 'речь', 'последний', 'некоторый', 'война', '8', 'стоить', 'иметь', 'контент', 'журнал', 'кинопоиск', 'жить', 'практика', 'информация', 'результат', 'a1', 'лекция', 'react', 'телеграм', 'уник', 'подошва', 'москва', 'карьера', 'востребовать', 'следующий', 'условие', '📝', 'поиск', 'рабочий', 'высокий', '3d', 'происходить', 'проходить', 'представить', 'интересно', 'режим', 'два', 'education', 'случай', 'proglib', 'девушка', 'выйти', 'сообщение', 'стоимость', 'эксперт', 'видеть', 'провести', 'помогать', 'код', '198397087', 'album', 'bit', 'доступный', 'отличный', 'известный', '👉🏻', 'рассмотреть', 'современный', 'английский', 'никто', 'фото', 'создание', 'крупный', 'срок', 'предлагать', 'час', 'думать', '100', 'начинающий', '📢', '📮', 'ksanadeng', 'жaнp', 'главное', '⭐', 'форма', 'часть', 'общий', 'гражданин', 'выдать', 'инженер', 'нахуй', 'ия', 'бизнес', '26', 'управление', 'инструмент', 'точно', 'клуб', 'крутой', 'сложный', 'фотография', 'картина', 'dw', 'набор', 'cinetexts', 'музыкальный', 'решать', 'занять', 'буква', 'смысл', '2021', 'процесс', 'искус ...

# %% [markdown]
# Создадим функцию для преобразования информации о группе в вектор. В векторе содержатся данные о названии группы, статусе и описании, численные значения о группе (число подписчиков и т.п.), а также данные о 15 постах группы (текст поста, число лайков, репостов, прикрепленных фото и т.п.). Также написана функция для получения только текстовых признаков группы.

# %%
def get_vectorized_group_info(group_info):
    group_vector = []
    if lemmatize(group_info[1]) is not None:
        group_vector.extend(get_themes_characteristics(lemmatize(group_info[1])))
    else:
        group_vector.extend([0.] * 4)
    if lemmatize(group_info[2]) is not None:
        group_vector.extend(get_themes_characteristics(lemmatize(group_info[2])))
    else:
        group_vector.extend([0.] * 4)
    if lemmatize(group_info[3]) is not None:
        group_vector.extend(get_themes_characteristics(lemmatize(group_info[3])))
    else:
        group_vector.extend([0.] * 4)
    group_vector.extend(group_info[6:11])
    posts = json.loads(group_info[12])
    for post in posts:
        if lemmatize(post['text']) is not None:
            group_vector.extend(get_themes_characteristics(lemmatize(post['text'])))
        else:
            group_vector.extend([0.] * 4)
        group_vector.extend([post['likes'], post['reposts'], post['photos_number'], post['music_number'], 
                        post['video_number'], post['links_number'], post['docs_number']])
    while len(group_vector) < 3 * 4 + 5 + 15 * 11:
        group_vector.extend([0.] * 11)
    
    return group_vector


def get_vectorized_group_info_only_texts(group_info):
    group_vector = []
    if lemmatize(group_info[1]) is not None:
        group_vector.extend(get_themes_characteristics(lemmatize(group_info[1])))
    else:
        group_vector.extend([0.] * 4)
    if lemmatize(group_info[2]) is not None:
        group_vector.extend(get_themes_characteristics(lemmatize(group_info[2])))
    else:
        group_vector.extend([0.] * 4)
    if lemmatize(group_info[3]) is not None:
        group_vector.extend(get_themes_characteristics(lemmatize(group_info[3])))
    else:
        group_vector.extend([0.] * 4)
    posts = json.loads(group_info[12])
    for post in posts:
        if lemmatize(post['text']) is not None:
            group_vector.extend(get_themes_characteristics(lemmatize(post['text'])))
        else:
            group_vector.extend([0.] * 4)
    while len(group_vector) < 3 * 4 + 15 * 4:
        group_vector.extend([0.] * 4)
    
    return group_vector

# %% [markdown]
# Сформируем векторы входных и выходных данных для моделей, используя написанные функции. Создадим следующие наборы: датасет со всеми возможными входными данными, датасет без информации о постах и датасет, содержащий только информацию о текстовых данных.

# %%
themes = {
    'Кино': 1,
    'Немецкий язык': 2,
    'Программирование': 3,
    'Мемы': 4,
    'Другое': 0
}
themes_inverse = {
    1: 'Кино',
    2: 'Немецкий язык',
    3: 'Программирование',
    4: 'Мемы',
    0: 'Другое'
}

train_input_full = []
train_input_no_posts = []
train_input_only_texts = []
train_output = []
for element in train_data:
    train_input_full.append(get_vectorized_group_info(element))
    train_input_no_posts.append(train_input_full[-1][:17])
    train_input_only_texts.append(get_vectorized_group_info_only_texts(element))
    train_output.append(themes[element[13]])
    
test_input_full = []
test_input_no_posts = []
test_input_only_texts = []
test_output = []
for element in test_data:
    test_input_full.append(get_vectorized_group_info(element))
    test_input_no_posts.append(test_input_full[-1][:17])
    test_input_only_texts.append(get_vectorized_group_info_only_texts(element))
    test_output.append(themes[element[13]])

# %% [markdown]
# Обучим классификатор RidgeClassifier на полных данных и посчитаем метрики для оценки модели:

# %%
model_ridge_full = linear_model.RidgeClassifier()
model_ridge_full.fit(train_input_full, train_output)

predicted_test_ridge = model_ridge_full.predict(test_input_full)
print(metrics.classification_report(predicted_test_ridge, test_output, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.50      0.67      0.57         3
#            2       0.50      0.29      0.36         7
#            3       0.33      1.00      0.50         2
#            4       0.50      0.25      0.33         4
#
#     accuracy                           0.44        16
#    macro avg       0.46      0.55      0.44        16
# weighted avg       0.48      0.44      0.41        16

# %% [markdown]
# Precision: для класса 1 и класса 2 равна 1.00, что указывает на то, что когда модель предсказывает эти классы, она верна в 100% случаев. Но precision для классов 3 и 4 составляет 0,00, что говорит о том, что модель не предсказала правильно выборки для этих классов.
#
# Recall: для класса 1 составляет 0,33, что означает, что только 33% фактических образцов класса 1 были правильно идентифицированы моделью. Для класса 2 равна 0,00, что указывает на то, что модели не удалось идентифицировать какие-либо выборки класса 2. С другой стороны, для классов 3 и 4 равна 1,00, что предполагает, что модель правильно предсказала все выборки для этих классов.
#
# F1-score: низкие оценки указывают на то, что производительность модели неудовлетворительна для большинства классов.
#
# Accuracy: общая точность модели составляет 0,17, что означает, что только 17% прогнозов были правильными. Такая низкая точность говорит о том, что модель плохо работает на тестовых данных.
#
# RidgeClassifier, обученный на полном наборе данных, похоже, плохо обобщает тестовые данные на основе низкой точности, отзыва и F1-показателей. Стоит изучить данные и рассмотреть альтернативные модели или представления признаков, чтобы повысить эффективность классификации.

# %% [markdown]
# Для данных, не использующих информацию о постах:

# %%
model_ridge_no_posts = linear_model.RidgeClassifier()
model_ridge_no_posts.fit(train_input_no_posts, train_output)

predicted_test_no_posts = model_ridge_no_posts.predict(test_input_no_posts)
print(metrics.classification_report(predicted_test_no_posts, test_output, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.75      0.60      0.67         5
#            2       0.75      0.60      0.67         5
#            3       0.33      1.00      0.50         2
#            4       0.50      0.25      0.33         4
#
#     accuracy                           0.56        16
#    macro avg       0.58      0.61      0.54        16
# weighted avg       0.64      0.56      0.56        16

# %% [markdown]
# Таким образом, RidgeClassifier, обученный на данных без информации о постах, демонстрирует ограниченную производительность. Модель хорошо работает для класса 3, достигая идеальной точности, отзыва и оценки F1. Однако он не может правильно предсказать какие-либо выборки для класса 1 и класса 4 и полностью пропускает класс 2. Общая точность предполагает, что производительность модели скромная. Для улучшения результатов классификации может потребоваться дальнейший анализ и возможные корректировки модели или представления данных.

# %% [markdown]
# Для данных, использующих только текстовую информацию:

# %%
model_ridge_only_texts = linear_model.RidgeClassifier()
model_ridge_only_texts.fit(train_input_only_texts, train_output)

predicted_test_only_texts = model_ridge_only_texts.predict(test_input_only_texts)
print(metrics.classification_report(predicted_test_only_texts, test_output, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         4
#            2       0.75      0.75      0.75         4
#            3       0.67      0.80      0.73         5
#            4       0.50      0.33      0.40         3
#
#     accuracy                           0.75        16
#    macro avg       0.73      0.72      0.72        16
# weighted avg       0.74      0.75      0.74        16

# %% [markdown]
# Таким образом, RidgeClassifier, обученный на данных только с текстовой информацией, демонстрирует ограниченную производительность. Модель хорошо работает в прогнозировании класса 4, достигая идеального отзыва и разумной точности и оценки F1. Однако он не может правильно предсказать ни одну выборку для класса 1 и класса 2, а его производительность для класса 3 является умеренной.

# %% [markdown]
# Обучим модели многослойного перцептрона на наших данных, чтобы сравнить результат ее работы с RidgeClassifier:

# %%
np_train_input_full = np.array(train_input_full)
np_test_input_full = np.array(test_input_full)

train_output_onehot = keras.utils.to_categorical(np.array(train_output))

model_seq_full = keras.Sequential([
    keras.layers.Dense(np_train_input_full.shape[1], activation='elu'),
    keras.layers.Dense(100, activation='elu'),
    keras.layers.Dense(60, activation='elu'),
    keras.layers.Dense(train_output_onehot.shape[1], activation='softmax')
])

model_seq_full.compile(optimizer='adam',
                      loss='categorical_crossentropy',
                      metrics=['accuracy', keras.metrics.Precision(), keras.metrics.Recall()])

history_seq_full = model_seq_full.fit(np_train_input_full, train_output_onehot, epochs=100, verbose=0)

predicted_seq_test_full = model_seq_full.predict(np_test_input_full)
predicted_res_test_full = []
for elem in predicted_seq_test_full:
    max_index = 0
    for i in range(5):
        if elem[i] > elem[max_index]:
            max_index = i
    predicted_res_test_full.append(max_index)

print(metrics.classification_report(predicted_res_test_full, test_output, zero_division=1))
# Out:
# 1/1 [==============================] - 0s 138ms/step
#               precision    recall  f1-score   support
#
#            1       1.00      0.33      0.50        12
#            2       0.00      1.00      0.00         0
#            3       0.17      0.50      0.25         2
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.31        16
#    macro avg       0.29      0.46      0.19        16
# weighted avg       0.77      0.31      0.41        16

# %%
np_train_input_no_posts = np.array(train_input_no_posts)
np_test_input_no_posts = np.array(test_input_no_posts)

model_seq_no_posts = keras.Sequential([
    keras.layers.Dense(np_train_input_no_posts.shape[1], activation='elu'),
    keras.layers.Dense(100, activation='elu'),
    keras.layers.Dense(60, activation='elu'),
    keras.layers.Dense(train_output_onehot.shape[1], activation='softmax')
])

model_seq_no_posts.compile(optimizer='adam',
                          loss='categorical_crossentropy',
                          metrics=['accuracy', keras.metrics.Precision(), keras.metrics.Recall()])

history_seq_no_posts = model_seq_no_posts.fit(np_train_input_no_posts, train_output_onehot, epochs=100, verbose=0)

predicted_seq_test_no_posts = model_seq_no_posts.predict(np_test_input_no_posts)
predicted_res_test_no_posts = []
for elem in predicted_seq_test_no_posts:
    max_index = 0
    for i in range(5):
        if elem[i] > elem[max_index]:
            max_index = i
    predicted_res_test_no_posts.append(max_index)

print(metrics.classification_report(predicted_res_test_no_posts, test_output, zero_division=1))
# Out:
# 1/1 [==============================] - 0s 81ms/step
#               precision    recall  f1-score   support
#
#            1       1.00      0.67      0.80         6
#            2       0.00      1.00      0.00         0
#            3       0.83      0.50      0.62        10
#            4       0.00      1.00      0.00         0
#
#     accuracy                           0.56        16
#    macro avg       0.46      0.79      0.36        16
# weighted avg       0.90      0.56      0.69        16

# %%
@tf.function
def get_max_index(elem):
    max_index = 0
    for i in range(5):
        if elem[i] > elem[max_index]:
            max_index = i
    return max_index

np_train_input_only_texts = np.array(train_input_only_texts)
np_test_input_only_texts = np.array(test_input_only_texts)

model_seq_only_texts = keras.Sequential([
    keras.layers.Dense(np_train_input_only_texts.shape[1], activation='elu'),
    keras.layers.Dense(100, activation='elu'),
    keras.layers.Dense(60, activation='elu'),
    keras.layers.Dense(train_output_onehot.shape[1], activation='softmax')
])

model_seq_only_texts.compile(optimizer='adam',
                             loss='categorical_crossentropy',
                             metrics=['accuracy', keras.metrics.Precision(), keras.metrics.Recall()])

history_seq_only_texts = model_seq_only_texts.fit(np_train_input_only_texts, train_output_onehot, epochs=100, verbose=0)

predicted_seq_test_only_texts = model_seq_only_texts.predict(np_test_input_only_texts)
predicted_res_test_only_texts = []

for elem in predicted_seq_test_only_texts:
    predicted_res_test_only_texts.append(get_max_index(elem))

print(metrics.classification_report(predicted_res_test_only_texts, test_output, zero_division=1))
# Out:
# 1/1 [==============================] - 0s 133ms/step
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         4
#            2       0.75      0.75      0.75         4
#            3       0.67      0.80      0.73         5
#            4       0.50      0.33      0.40         3
#
#     accuracy                           0.75        16
#    macro avg       0.73      0.72      0.72        16
# weighted avg       0.74      0.75      0.74        16

# %% [markdown]
# Сохраним обученные модели для дальнейшего использования:

# %%
w2v_model.save("models/word2vec.model")
joblib.dump(model_ridge_full, 'models/model_ridge_full.pkl')
joblib.dump(model_ridge_no_posts, 'models/model_ridge_no_posts.pkl')
joblib.dump(model_ridge_only_texts, 'models/model_ridge_only_texts.pkl')
model_seq_full.save('models/model_seq_full.h5')
model_seq_no_posts.save('models/model_seq_no_posts.h5')
model_seq_only_texts.save('models/model_seq_only_texts.h5')
